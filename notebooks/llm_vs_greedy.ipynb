# %% [markdown]
# # LLM vs Greedy playground
#
# Run end-to-end games between the LLM agent (via OpenRouter) and a baseline Greedy agent.
#
# Requirements:
# - Set `OPENROUTER_API_KEY` in your environment.
# - Network access enabled.
#
# You can adjust seeds, budgets, and model names as needed.

# %%
import os
from azul_engine import GameEngine, LLMAgent, GreedyFillAgent, play_game


# Configure agents
llm_agent = LLMAgent(model="openai/gpt-oss-120b", provider_priority=("fireworks", "together", "novita/fp4"))
llm_agent2 = LLMAgent(model="openai/gpt-oss-20b", provider_priority=("fireworks", "together", "novita/fp4"))
greedy_agent = GreedyFillAgent()

assert os.getenv("OPENROUTER_API_KEY"), "Set OPENROUTER_API_KEY before running"

# %%
def play_llm_vs_greedy(seed: int = 0):
    engine = GameEngine(seed=seed)
    state = engine.reset()
    agents = [llm_agent, llm_agent2]
    turn = 0
    while not state.is_terminal():
        current = state.current_player
        agent = agents[current]
        action = agent.select_action(state)
        state = engine.step(action)
        print(state)
        print([p.score for p in state.players])
        print(current, agent)
        print(action)
        turn += 1
    return state

state = play_llm_vs_greedy(seed=0)
scores = [p.score for p in state.players]
scores
# Out:
# GameState(players=[PlayerBoard(pattern_lines=[[], [<TileColor.RED: 'red'>, <TileColor.RED: 'red'>], [], [], []], wall=[[False, False, False, False, False], [False, False, False, False, False], [False, False, False, False, False], [False, False, False, False, False], [False, False, False, False, False]], floor_line=[], has_first_player_token=False, score=0), PlayerBoard(pattern_lines=[[], [], [], [], []], wall=[[False, False, False, False, False], [False, False, False, False, False], [False, False, False, False, False], [False, False, False, False, False], [False, False, False, False, False]], floor_line=[], has_first_player_token=False, score=0)], current_player=1, phase=<GamePhase.DRAFTING: 'drafting'>, supply=Supply(bag=[<TileColor.YELLOW: 'yellow'>, <TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>, <TileColor.RED: 'red'>, <TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>, <TileColor.WHITE: 'white'>, <TileColor.WHITE: 'white'>, <TileColor.RED: 'red'>, <TileColor.BLUE: 'blue'>, <TileColor.BLACK: 'black'>, <TileColor.RED: 'red'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.BLUE: 'blue'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>, <TileColor.YELLOW: 'yellow'>, <TileColor.BLUE: 'blue'>, <TileColor.RED: 'red'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.WHITE: 'white'>, <TileColor.YELLOW: 'yellow'>, <TileColor.WHITE: 'white'>, <TileColor.WHITE: 'white'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.WHITE: 'white'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.WHITE: 'white'>, <TileColor.RED: 'red'>, <TileColor.BLUE: 'blue'>, <TileColor.WHITE: 'white'>, <TileColor.BLACK: 'black'>, <TileColor.BLUE: 'blue'>, <TileColor.YELLOW: 'yellow'>, <TileColor.BLUE: 'blue'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.BLACK: 'black'>, <TileColor.RED: 'red'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.RED: 'red'>, <TileColor.BLACK: 'black'>, <TileColor.YELLOW: 'yellow'>, <TileColor.WHITE: 'white'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.BLUE: 'blue'>, <TileColor.BLACK: 'black'>, <TileColor.YELLOW: 'yellow'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.BLUE: 'blue'>, <TileColor.WHITE: 'white'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.YELLOW: 'yellow'>, <TileColor.RED: 'red'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.RED: 'red'>, <TileColor.BLUE: 'blue'>, <TileColor.WHITE: 'white'>, <TileColor.YELLOW: 'yellow'>, <TileColor.BLUE: 'blue'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>], discard=[], factories=[[], [<TileColor.YELLOW: 'yellow'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.RED: 'red'>], [<TileColor.YELLOW: 'yellow'>, <TileColor.BLACK: 'black'>, <TileColor.RED: 'red'>, <TileColor.BLACK: 'black'>], [<TileColor.YELLOW: 'yellow'>, <TileColor.BLACK: 'black'>, <TileColor.BLUE: 'blue'>, <TileColor.YELLOW: 'yellow'>], [<TileColor.WHITE: 'white'>, <TileColor.BLUE: 'blue'>, <TileColor.BLACK: 'black'>, <TileColor.YELLOW: 'yellow'>]], center=[<TileColor.WHITE: 'white'>, <TileColor.BLUE: 'blue'>]), round_number=1, first_player_token_in_center=True, first_player_index=0, round_log=[])
# [0, 0]
# 0 LLMAgent(model='openai/gpt-oss-120b', last_raw='{"action_id": 12, "rationale": "Takes two reds, exactly fills pattern line 2 (capacity 2) with no overflow, maximizing tile placement early in the game."}', last_reasoning=None, provider_priority=('fireworks', 'together', 'novita/fp4'), last_status=200, last_error=None)
# Action(source_index=0, color=<TileColor.RED: 'red'>, pattern_line=1, take_first_player_token=False)
# GameState(players=[PlayerBoard(pattern_lines=[[], [<TileColor.RED: 'red'>, <TileColor.RED: 'red'>], [], [], []], wall=[[False, False, False, False, False], [False, False, False, False, False], [False, False, False, False, False], [False, False, False, False, False], [False, False, False, False, False]], floor_line=[], has_first_player_token=False, score=0), PlayerBoard(pattern_lines=[[], [], [<TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>], [], []], wall=[[False, False, False, False, False], [False, False, False, False, False], [False, False, False, False, False], [False, False, False, False, False], [False, False, False, False, False]], floor_line=[], has_first_player_token=False, score=0)], current_player=0, phase=<GamePhase.DRAFTING: 'drafting'>, supply=Supply(bag=[<TileColor.YELLOW: 'yellow'>, <TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>, <TileColor.RED: 'red'>, <TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>, <TileColor.WHITE: 'white'>, <TileColor.WHITE: 'white'>, <TileColor.RED: 'red'>, <TileColor.BLUE: 'blue'>, <TileColor.BLACK: 'black'>, <TileColor.RED: 'red'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.BLUE: 'blue'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>, <TileColor.YELLOW: 'yellow'>, <TileColor.BLUE: 'blue'>, <TileColor.RED: 'red'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.WHITE: 'white'>, <TileColor.YELLOW: 'yellow'>, <TileColor.WHITE: 'white'>, <TileColor.WHITE: 'white'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.WHITE: 'white'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.WHITE: 'white'>, <TileColor.RED: 'red'>, <TileColor.BLUE: 'blue'>, <TileColor.WHITE: 'white'>, <TileColor.BLACK: 'black'>, <TileColor.BLUE: 'blue'>, <TileColor.YELLOW: 'yellow'>, <TileColor.BLUE: 'blue'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.BLACK: 'black'>, <TileColor.RED: 'red'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.RED: 'red'>, <TileColor.BLACK: 'black'>, <TileColor.YELLOW: 'yellow'>, <TileColor.WHITE: 'white'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.BLUE: 'blue'>, <TileColor.BLACK: 'black'>, <TileColor.YELLOW: 'yellow'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.BLUE: 'blue'>, <TileColor.WHITE: 'white'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.YELLOW: 'yellow'>, <TileColor.RED: 'red'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.RED: 'red'>, <TileColor.BLUE: 'blue'>, <TileColor.WHITE: 'white'>, <TileColor.YELLOW: 'yellow'>, <TileColor.BLUE: 'blue'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>], discard=[], factories=[[], [], [<TileColor.YELLOW: 'yellow'>, <TileColor.BLACK: 'black'>, <TileColor.RED: 'red'>, <TileColor.BLACK: 'black'>], [<TileColor.YELLOW: 'yellow'>, <TileColor.BLACK: 'black'>, <TileColor.BLUE: 'blue'>, <TileColor.YELLOW: 'yellow'>], [<TileColor.WHITE: 'white'>, <TileColor.BLUE: 'blue'>, <TileColor.BLACK: 'black'>, <TileColor.YELLOW: 'yellow'>]], center=[<TileColor.WHITE: 'white'>, <TileColor.BLUE: 'blue'>, <TileColor.YELLOW: 'yellow'>, <TileColor.RED: 'red'>]), round_number=1, first_player_token_in_center=True, first_player_index=0, round_log=[])
# [0, 0]
# 1 LLMAgent(model='openai/gpt-oss-20b', last_raw='{"action_id": 25, "rationale": "Take 2 black tiles from factory 1 to line 3 for maximum immediate points."}', last_reasoning=None, provider_priority=('fireworks', 'together', 'novita/fp4'), last_status=200, last_error=None)
# Action(source_index=1, color=<TileColor.BLACK: 'black'>, pattern_line=2, take_first_player_token=False)
# GameState(players=[PlayerBoard(pattern_lines=[[], [<TileColor.RED: 'red'>, <TileColor.RED: 'red'>], [], [], [<TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>]], wall=[[False, False, False, False, False], [False, False, False, False, False], [False, False, False, False, False], [False, False, False, False, False], [False, False, False, False, False]], floor_line=[], has_first_player_token=False, score=0), PlayerBoard(pattern_lines=[[], [], [<TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>], [], []], wall=[[False, False, False, False, False], [False, False, False, False, False], [False, False, False, False, False], [False, False, False, False, False], [False, False, False, False, False]], floor_line=[], has_first_player_token=False, score=0)], current_player=1, phase=<GamePhase.DRAFTING: 'drafting'>, supply=Supply(bag=[<TileColor.YELLOW: 'yellow'>, <TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>, <TileColor.RED: 'red'>, <TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>, <TileColor.WHITE: 'white'>, <TileColor.WHITE: 'white'>, <TileColor.RED: 'red'>, <TileColor.BLUE: 'blue'>, <TileColor.BLACK: 'black'>, <TileColor.RED: 'red'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.BLUE: 'blue'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>, <TileColor.YELLOW: 'yellow'>, <TileColor.BLUE: 'blue'>, <TileColor.RED: 'red'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.WHITE: 'white'>, <TileColor.YELLOW: 'yellow'>, <TileColor.WHITE: 'white'>, <TileColor.WHITE: 'white'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.WHITE: 'white'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.WHITE: 'white'>, <TileColor.RED: 'red'>, <TileColor.BLUE: 'blue'>, <TileColor.WHITE: 'white'>, <TileColor.BLACK: 'black'>, <TileColor.BLUE: 'blue'>, <TileColor.YELLOW: 'yellow'>, <TileColor.BLUE: 'blue'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.BLACK: 'black'>, <TileColor.RED: 'red'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.RED: 'red'>, <TileColor.BLACK: 'black'>, <TileColor.YELLOW: 'yellow'>, <TileColor.WHITE: 'white'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.BLUE: 'blue'>, <TileColor.BLACK: 'black'>, <TileColor.YELLOW: 'yellow'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.BLUE: 'blue'>, <TileColor.WHITE: 'white'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.YELLOW: 'yellow'>, <TileColor.RED: 'red'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.RED: 'red'>, <TileColor.BLUE: 'blue'>, <TileColor.WHITE: 'white'>, <TileColor.YELLOW: 'yellow'>, <TileColor.BLUE: 'blue'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>], discard=[], factories=[[], [], [], [<TileColor.YELLOW: 'yellow'>, <TileColor.BLACK: 'black'>, <TileColor.BLUE: 'blue'>, <TileColor.YELLOW: 'yellow'>], [<TileColor.WHITE: 'white'>, <TileColor.BLUE: 'blue'>, <TileColor.BLACK: 'black'>, <TileColor.YELLOW: 'yellow'>]], center=[<TileColor.WHITE: 'white'>, <TileColor.BLUE: 'blue'>, <TileColor.YELLOW: 'yellow'>, <TileColor.RED: 'red'>, <TileColor.YELLOW: 'yellow'>, <TileColor.RED: 'red'>]), round_number=1, first_player_token_in_center=True, first_player_index=0, round_log=[])
# [0, 0]
# 0 LLMAgent(model='openai/gpt-oss-120b', last_raw='{"action_id": 16, "rationale": "Take the two black tiles from factory 2 and place them in pattern line 5, fitting the line capacity and avoiding overflow or the first-player token."}', last_reasoning=None, provider_priority=('fireworks', 'together', 'novita/fp4'), last_status=200, last_error=None)
# Action(source_index=2, color=<TileColor.BLACK: 'black'>, pattern_line=4, take_first_player_token=False)
# GameState(players=[PlayerBoard(pattern_lines=[[], [<TileColor.RED: 'red'>, <TileColor.RED: 'red'>], [], [], [<TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>]], wall=[[False, False, False, False, False], [False, False, False, False, False], [False, False, False, False, False], [False, False, False, False, False], [False, False, False, False, False]], floor_line=[], has_first_player_token=False, score=0), PlayerBoard(pattern_lines=[[], [<TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>], [<TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>], [], []], wall=[[False, False, False, False, False], [False, False, False, False, False], [False, False, False, False, False], [False, False, False, False, False], [False, False, False, False, False]], floor_line=[], has_first_player_token=True, score=0)], current_player=0, phase=<GamePhase.DRAFTING: 'drafting'>, supply=Supply(bag=[<TileColor.YELLOW: 'yellow'>, <TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>, <TileColor.RED: 'red'>, <TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>, <TileColor.WHITE: 'white'>, <TileColor.WHITE: 'white'>, <TileColor.RED: 'red'>, <TileColor.BLUE: 'blue'>, <TileColor.BLACK: 'black'>, <TileColor.RED: 'red'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.BLUE: 'blue'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>, <TileColor.YELLOW: 'yellow'>, <TileColor.BLUE: 'blue'>, <TileColor.RED: 'red'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.WHITE: 'white'>, <TileColor.YELLOW: 'yellow'>, <TileColor.WHITE: 'white'>, <TileColor.WHITE: 'white'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.WHITE: 'white'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.WHITE: 'white'>, <TileColor.RED: 'red'>, <TileColor.BLUE: 'blue'>, <TileColor.WHITE: 'white'>, <TileColor.BLACK: 'black'>, <TileColor.BLUE: 'blue'>, <TileColor.YELLOW: 'yellow'>, <TileColor.BLUE: 'blue'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.BLACK: 'black'>, <TileColor.RED: 'red'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.RED: 'red'>, <TileColor.BLACK: 'black'>, <TileColor.YELLOW: 'yellow'>, <TileColor.WHITE: 'white'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.BLUE: 'blue'>, <TileColor.BLACK: 'black'>, <TileColor.YELLOW: 'yellow'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.BLUE: 'blue'>, <TileColor.WHITE: 'white'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.YELLOW: 'yellow'>, <TileColor.RED: 'red'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.RED: 'red'>, <TileColor.BLUE: 'blue'>, <TileColor.WHITE: 'white'>, <TileColor.YELLOW: 'yellow'>, <TileColor.BLUE: 'blue'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>], discard=[], factories=[[], [], [], [<TileColor.YELLOW: 'yellow'>, <TileColor.BLACK: 'black'>, <TileColor.BLUE: 'blue'>, <TileColor.YELLOW: 'yellow'>], [<TileColor.WHITE: 'white'>, <TileColor.BLUE: 'blue'>, <TileColor.BLACK: 'black'>, <TileColor.YELLOW: 'yellow'>]], center=[<TileColor.WHITE: 'white'>, <TileColor.BLUE: 'blue'>, <TileColor.RED: 'red'>, <TileColor.RED: 'red'>]), round_number=1, first_player_token_in_center=False, first_player_index=1, round_log=[])
# [0, 0]
# 1 LLMAgent(model='openai/gpt-oss-20b', last_raw='{"action_id": 11, "rationale": "Take 2 yellows from center to line 4, grabbing the first‑player token with no floor overflow and setting up a future wall tile."}', last_reasoning=None, provider_priority=('fireworks', 'together', 'novita/fp4'), last_status=200, last_error=None)
# Action(source_index=-1, color=<TileColor.YELLOW: 'yellow'>, pattern_line=1, take_first_player_token=True)
# GameState(players=[PlayerBoard(pattern_lines=[[], [<TileColor.RED: 'red'>, <TileColor.RED: 'red'>], [<TileColor.RED: 'red'>, <TileColor.RED: 'red'>], [], [<TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>]], wall=[[False, False, False, False, False], [False, False, False, False, False], [False, False, False, False, False], [False, False, False, False, False], [False, False, False, False, False]], floor_line=[], has_first_player_token=False, score=0), PlayerBoard(pattern_lines=[[], [<TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>], [<TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>], [], []], wall=[[False, False, False, False, False], [False, False, False, False, False], [False, False, False, False, False], [False, False, False, False, False], [False, False, False, False, False]], floor_line=[], has_first_player_token=True, score=0)], current_player=1, phase=<GamePhase.DRAFTING: 'drafting'>, supply=Supply(bag=[<TileColor.YELLOW: 'yellow'>, <TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>, <TileColor.RED: 'red'>, <TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>, <TileColor.WHITE: 'white'>, <TileColor.WHITE: 'white'>, <TileColor.RED: 'red'>, <TileColor.BLUE: 'blue'>, <TileColor.BLACK: 'black'>, <TileColor.RED: 'red'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.BLUE: 'blue'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>, <TileColor.YELLOW: 'yellow'>, <TileColor.BLUE: 'blue'>, <TileColor.RED: 'red'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.WHITE: 'white'>, <TileColor.YELLOW: 'yellow'>, <TileColor.WHITE: 'white'>, <TileColor.WHITE: 'white'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.WHITE: 'white'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.WHITE: 'white'>, <TileColor.RED: 'red'>, <TileColor.BLUE: 'blue'>, <TileColor.WHITE: 'white'>, <TileColor.BLACK: 'black'>, <TileColor.BLUE: 'blue'>, <TileColor.YELLOW: 'yellow'>, <TileColor.BLUE: 'blue'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.BLACK: 'black'>, <TileColor.RED: 'red'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.RED: 'red'>, <TileColor.BLACK: 'black'>, <TileColor.YELLOW: 'yellow'>, <TileColor.WHITE: 'white'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.BLUE: 'blue'>, <TileColor.BLACK: 'black'>, <TileColor.YELLOW: 'yellow'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.BLUE: 'blue'>, <TileColor.WHITE: 'white'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.YELLOW: 'yellow'>, <TileColor.RED: 'red'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.RED: 'red'>, <TileColor.BLUE: 'blue'>, <TileColor.WHITE: 'white'>, <TileColor.YELLOW: 'yellow'>, <TileColor.BLUE: 'blue'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>], discard=[], factories=[[], [], [], [<TileColor.YELLOW: 'yellow'>, <TileColor.BLACK: 'black'>, <TileColor.BLUE: 'blue'>, <TileColor.YELLOW: 'yellow'>], [<TileColor.WHITE: 'white'>, <TileColor.BLUE: 'blue'>, <TileColor.BLACK: 'black'>, <TileColor.YELLOW: 'yellow'>]], center=[<TileColor.WHITE: 'white'>, <TileColor.BLUE: 'blue'>]), round_number=1, first_player_token_in_center=False, first_player_index=1, round_log=[])
# [0, 0]
# 0 LLMAgent(model='openai/gpt-oss-120b', last_raw='{"action_id": 20, "rationale": "Place the two reds from the center into pattern line 3 (capacity 3). No overflow, advances a line toward completion and sets up a red tile on the wall without incurring floor penalties."}', last_reasoning=None, provider_priority=('fireworks', 'together', 'novita/fp4'), last_status=200, last_error=None)
# Action(source_index=-1, color=<TileColor.RED: 'red'>, pattern_line=2, take_first_player_token=False)
# GameState(players=[PlayerBoard(pattern_lines=[[], [<TileColor.RED: 'red'>, <TileColor.RED: 'red'>], [<TileColor.RED: 'red'>, <TileColor.RED: 'red'>], [], [<TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>]], wall=[[False, False, False, False, False], [False, False, False, False, False], [False, False, False, False, False], [False, False, False, False, False], [False, False, False, False, False]], floor_line=[], has_first_player_token=False, score=0), PlayerBoard(pattern_lines=[[<TileColor.BLACK: 'black'>], [<TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>], [<TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>], [], []], wall=[[False, False, False, False, False], [False, False, False, False, False], [False, False, False, False, False], [False, False, False, False, False], [False, False, False, False, False]], floor_line=[], has_first_player_token=True, score=0)], current_player=0, phase=<GamePhase.DRAFTING: 'drafting'>, supply=Supply(bag=[<TileColor.YELLOW: 'yellow'>, <TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>, <TileColor.RED: 'red'>, <TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>, <TileColor.WHITE: 'white'>, <TileColor.WHITE: 'white'>, <TileColor.RED: 'red'>, <TileColor.BLUE: 'blue'>, <TileColor.BLACK: 'black'>, <TileColor.RED: 'red'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.BLUE: 'blue'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>, <TileColor.YELLOW: 'yellow'>, <TileColor.BLUE: 'blue'>, <TileColor.RED: 'red'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.WHITE: 'white'>, <TileColor.YELLOW: 'yellow'>, <TileColor.WHITE: 'white'>, <TileColor.WHITE: 'white'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.WHITE: 'white'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.WHITE: 'white'>, <TileColor.RED: 'red'>, <TileColor.BLUE: 'blue'>, <TileColor.WHITE: 'white'>, <TileColor.BLACK: 'black'>, <TileColor.BLUE: 'blue'>, <TileColor.YELLOW: 'yellow'>, <TileColor.BLUE: 'blue'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.BLACK: 'black'>, <TileColor.RED: 'red'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.RED: 'red'>, <TileColor.BLACK: 'black'>, <TileColor.YELLOW: 'yellow'>, <TileColor.WHITE: 'white'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.BLUE: 'blue'>, <TileColor.BLACK: 'black'>, <TileColor.YELLOW: 'yellow'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.BLUE: 'blue'>, <TileColor.WHITE: 'white'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.YELLOW: 'yellow'>, <TileColor.RED: 'red'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.RED: 'red'>, <TileColor.BLUE: 'blue'>, <TileColor.WHITE: 'white'>, <TileColor.YELLOW: 'yellow'>, <TileColor.BLUE: 'blue'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>], discard=[], factories=[[], [], [], [], [<TileColor.WHITE: 'white'>, <TileColor.BLUE: 'blue'>, <TileColor.BLACK: 'black'>, <TileColor.YELLOW: 'yellow'>]], center=[<TileColor.WHITE: 'white'>, <TileColor.BLUE: 'blue'>, <TileColor.YELLOW: 'yellow'>, <TileColor.BLUE: 'blue'>, <TileColor.YELLOW: 'yellow'>]), round_number=1, first_player_token_in_center=False, first_player_index=1, round_log=[])
# [0, 0]
# 1 LLMAgent(model='openai/gpt-oss-20b', last_raw='{"action_id": 2, "rationale": "Place a black tile into line 1 for a quick +2 point gain."}', last_reasoning=None, provider_priority=('fireworks', 'together', 'novita/fp4'), last_status=200, last_error=None)
# Action(source_index=3, color=<TileColor.BLACK: 'black'>, pattern_line=0, take_first_player_token=False)
# GameState(players=[PlayerBoard(pattern_lines=[[], [<TileColor.RED: 'red'>, <TileColor.RED: 'red'>], [<TileColor.RED: 'red'>, <TileColor.RED: 'red'>], [<TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>], [<TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>]], wall=[[False, False, False, False, False], [False, False, False, False, False], [False, False, False, False, False], [False, False, False, False, False], [False, False, False, False, False]], floor_line=[], has_first_player_token=False, score=0), PlayerBoard(pattern_lines=[[<TileColor.BLACK: 'black'>], [<TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>], [<TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>], [], []], wall=[[False, False, False, False, False], [False, False, False, False, False], [False, False, False, False, False], [False, False, False, False, False], [False, False, False, False, False]], floor_line=[], has_first_player_token=True, score=0)], current_player=1, phase=<GamePhase.DRAFTING: 'drafting'>, supply=Supply(bag=[<TileColor.YELLOW: 'yellow'>, <TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>, <TileColor.RED: 'red'>, <TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>, <TileColor.WHITE: 'white'>, <TileColor.WHITE: 'white'>, <TileColor.RED: 'red'>, <TileColor.BLUE: 'blue'>, <TileColor.BLACK: 'black'>, <TileColor.RED: 'red'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.BLUE: 'blue'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>, <TileColor.YELLOW: 'yellow'>, <TileColor.BLUE: 'blue'>, <TileColor.RED: 'red'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.WHITE: 'white'>, <TileColor.YELLOW: 'yellow'>, <TileColor.WHITE: 'white'>, <TileColor.WHITE: 'white'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.WHITE: 'white'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.WHITE: 'white'>, <TileColor.RED: 'red'>, <TileColor.BLUE: 'blue'>, <TileColor.WHITE: 'white'>, <TileColor.BLACK: 'black'>, <TileColor.BLUE: 'blue'>, <TileColor.YELLOW: 'yellow'>, <TileColor.BLUE: 'blue'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.BLACK: 'black'>, <TileColor.RED: 'red'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.RED: 'red'>, <TileColor.BLACK: 'black'>, <TileColor.YELLOW: 'yellow'>, <TileColor.WHITE: 'white'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.BLUE: 'blue'>, <TileColor.BLACK: 'black'>, <TileColor.YELLOW: 'yellow'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.BLUE: 'blue'>, <TileColor.WHITE: 'white'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.YELLOW: 'yellow'>, <TileColor.RED: 'red'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.RED: 'red'>, <TileColor.BLUE: 'blue'>, <TileColor.WHITE: 'white'>, <TileColor.YELLOW: 'yellow'>, <TileColor.BLUE: 'blue'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>], discard=[], factories=[[], [], [], [], [<TileColor.WHITE: 'white'>, <TileColor.BLUE: 'blue'>, <TileColor.BLACK: 'black'>, <TileColor.YELLOW: 'yellow'>]], center=[<TileColor.WHITE: 'white'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>]), round_number=1, first_player_token_in_center=False, first_player_index=1, round_log=[])
# [0, 0]
# 0 LLMAgent(model='openai/gpt-oss-120b', last_raw='{"action_id": 10, "rationale": "Place the two blue tiles from the center into the empty line 4, filling two slots and keeping future capacity to complete the line with the remaining blue tile."}', last_reasoning=None, provider_priority=('fireworks', 'together', 'novita/fp4'), last_status=200, last_error=None)
# Action(source_index=-1, color=<TileColor.BLUE: 'blue'>, pattern_line=3, take_first_player_token=False)
# GameState(players=[PlayerBoard(pattern_lines=[[], [<TileColor.RED: 'red'>, <TileColor.RED: 'red'>], [<TileColor.RED: 'red'>, <TileColor.RED: 'red'>], [<TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>], [<TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>]], wall=[[False, False, False, False, False], [False, False, False, False, False], [False, False, False, False, False], [False, False, False, False, False], [False, False, False, False, False]], floor_line=[], has_first_player_token=False, score=0), PlayerBoard(pattern_lines=[[<TileColor.BLACK: 'black'>], [<TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>], [<TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>], [<TileColor.BLUE: 'blue'>], []], wall=[[False, False, False, False, False], [False, False, False, False, False], [False, False, False, False, False], [False, False, False, False, False], [False, False, False, False, False]], floor_line=[], has_first_player_token=True, score=0)], current_player=0, phase=<GamePhase.DRAFTING: 'drafting'>, supply=Supply(bag=[<TileColor.YELLOW: 'yellow'>, <TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>, <TileColor.RED: 'red'>, <TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>, <TileColor.WHITE: 'white'>, <TileColor.WHITE: 'white'>, <TileColor.RED: 'red'>, <TileColor.BLUE: 'blue'>, <TileColor.BLACK: 'black'>, <TileColor.RED: 'red'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.BLUE: 'blue'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>, <TileColor.YELLOW: 'yellow'>, <TileColor.BLUE: 'blue'>, <TileColor.RED: 'red'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.WHITE: 'white'>, <TileColor.YELLOW: 'yellow'>, <TileColor.WHITE: 'white'>, <TileColor.WHITE: 'white'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.WHITE: 'white'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.WHITE: 'white'>, <TileColor.RED: 'red'>, <TileColor.BLUE: 'blue'>, <TileColor.WHITE: 'white'>, <TileColor.BLACK: 'black'>, <TileColor.BLUE: 'blue'>, <TileColor.YELLOW: 'yellow'>, <TileColor.BLUE: 'blue'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.BLACK: 'black'>, <TileColor.RED: 'red'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.RED: 'red'>, <TileColor.BLACK: 'black'>, <TileColor.YELLOW: 'yellow'>, <TileColor.WHITE: 'white'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.BLUE: 'blue'>, <TileColor.BLACK: 'black'>, <TileColor.YELLOW: 'yellow'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.BLUE: 'blue'>, <TileColor.WHITE: 'white'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.YELLOW: 'yellow'>, <TileColor.RED: 'red'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.RED: 'red'>, <TileColor.BLUE: 'blue'>, <TileColor.WHITE: 'white'>, <TileColor.YELLOW: 'yellow'>, <TileColor.BLUE: 'blue'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>], discard=[], factories=[[], [], [], [], []], center=[<TileColor.WHITE: 'white'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.WHITE: 'white'>, <TileColor.BLACK: 'black'>, <TileColor.YELLOW: 'yellow'>]), round_number=1, first_player_token_in_center=False, first_player_index=1, round_log=[])
# [0, 0]
# 1 LLMAgent(model='openai/gpt-oss-20b', last_raw='{"action_id": 1, "rationale": "Place blue into line 4 to avoid floor penalty and move closer to completing the line."}', last_reasoning=None, provider_priority=('fireworks', 'together', 'novita/fp4'), last_status=200, last_error=None)
# Action(source_index=4, color=<TileColor.BLUE: 'blue'>, pattern_line=3, take_first_player_token=False)
# GameState(players=[PlayerBoard(pattern_lines=[[<TileColor.WHITE: 'white'>], [<TileColor.RED: 'red'>, <TileColor.RED: 'red'>], [<TileColor.RED: 'red'>, <TileColor.RED: 'red'>], [<TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>], [<TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>]], wall=[[False, False, False, False, False], [False, False, False, False, False], [False, False, False, False, False], [False, False, False, False, False], [False, False, False, False, False]], floor_line=[<TileColor.WHITE: 'white'>], has_first_player_token=False, score=0), PlayerBoard(pattern_lines=[[<TileColor.BLACK: 'black'>], [<TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>], [<TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>], [<TileColor.BLUE: 'blue'>], []], wall=[[False, False, False, False, False], [False, False, False, False, False], [False, False, False, False, False], [False, False, False, False, False], [False, False, False, False, False]], floor_line=[], has_first_player_token=True, score=0)], current_player=1, phase=<GamePhase.DRAFTING: 'drafting'>, supply=Supply(bag=[<TileColor.YELLOW: 'yellow'>, <TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>, <TileColor.RED: 'red'>, <TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>, <TileColor.WHITE: 'white'>, <TileColor.WHITE: 'white'>, <TileColor.RED: 'red'>, <TileColor.BLUE: 'blue'>, <TileColor.BLACK: 'black'>, <TileColor.RED: 'red'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.BLUE: 'blue'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>, <TileColor.YELLOW: 'yellow'>, <TileColor.BLUE: 'blue'>, <TileColor.RED: 'red'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.WHITE: 'white'>, <TileColor.YELLOW: 'yellow'>, <TileColor.WHITE: 'white'>, <TileColor.WHITE: 'white'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.WHITE: 'white'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.WHITE: 'white'>, <TileColor.RED: 'red'>, <TileColor.BLUE: 'blue'>, <TileColor.WHITE: 'white'>, <TileColor.BLACK: 'black'>, <TileColor.BLUE: 'blue'>, <TileColor.YELLOW: 'yellow'>, <TileColor.BLUE: 'blue'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.BLACK: 'black'>, <TileColor.RED: 'red'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.RED: 'red'>, <TileColor.BLACK: 'black'>, <TileColor.YELLOW: 'yellow'>, <TileColor.WHITE: 'white'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.BLUE: 'blue'>, <TileColor.BLACK: 'black'>, <TileColor.YELLOW: 'yellow'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.BLUE: 'blue'>, <TileColor.WHITE: 'white'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.YELLOW: 'yellow'>, <TileColor.RED: 'red'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.RED: 'red'>, <TileColor.BLUE: 'blue'>, <TileColor.WHITE: 'white'>, <TileColor.YELLOW: 'yellow'>, <TileColor.BLUE: 'blue'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>], discard=[], factories=[[], [], [], [], []], center=[<TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.BLACK: 'black'>, <TileColor.YELLOW: 'yellow'>]), round_number=1, first_player_token_in_center=False, first_player_index=1, round_log=[])
# [0, 0]
# 0 LLMAgent(model='openai/gpt-oss-120b', last_raw='{\n  "action_id": 2,\n  "rationale": "Fills the 1‑capacity line for an immediate tile placement and scores 1 point, the best immediate gain."\n}', last_reasoning=None, provider_priority=('fireworks', 'together', 'novita/fp4'), last_status=200, last_error=None)
# Action(source_index=-1, color=<TileColor.WHITE: 'white'>, pattern_line=0, take_first_player_token=False)
# GameState(players=[PlayerBoard(pattern_lines=[[<TileColor.WHITE: 'white'>], [<TileColor.RED: 'red'>, <TileColor.RED: 'red'>], [<TileColor.RED: 'red'>, <TileColor.RED: 'red'>], [<TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>], [<TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>]], wall=[[False, False, False, False, False], [False, False, False, False, False], [False, False, False, False, False], [False, False, False, False, False], [False, False, False, False, False]], floor_line=[<TileColor.WHITE: 'white'>], has_first_player_token=False, score=0), PlayerBoard(pattern_lines=[[<TileColor.BLACK: 'black'>], [<TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>], [<TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>], [<TileColor.BLUE: 'blue'>], [<TileColor.BLACK: 'black'>]], wall=[[False, False, False, False, False], [False, False, False, False, False], [False, False, False, False, False], [False, False, False, False, False], [False, False, False, False, False]], floor_line=[], has_first_player_token=True, score=0)], current_player=0, phase=<GamePhase.DRAFTING: 'drafting'>, supply=Supply(bag=[<TileColor.YELLOW: 'yellow'>, <TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>, <TileColor.RED: 'red'>, <TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>, <TileColor.WHITE: 'white'>, <TileColor.WHITE: 'white'>, <TileColor.RED: 'red'>, <TileColor.BLUE: 'blue'>, <TileColor.BLACK: 'black'>, <TileColor.RED: 'red'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.BLUE: 'blue'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>, <TileColor.YELLOW: 'yellow'>, <TileColor.BLUE: 'blue'>, <TileColor.RED: 'red'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.WHITE: 'white'>, <TileColor.YELLOW: 'yellow'>, <TileColor.WHITE: 'white'>, <TileColor.WHITE: 'white'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.WHITE: 'white'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.WHITE: 'white'>, <TileColor.RED: 'red'>, <TileColor.BLUE: 'blue'>, <TileColor.WHITE: 'white'>, <TileColor.BLACK: 'black'>, <TileColor.BLUE: 'blue'>, <TileColor.YELLOW: 'yellow'>, <TileColor.BLUE: 'blue'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.BLACK: 'black'>, <TileColor.RED: 'red'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.RED: 'red'>, <TileColor.BLACK: 'black'>, <TileColor.YELLOW: 'yellow'>, <TileColor.WHITE: 'white'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.BLUE: 'blue'>, <TileColor.BLACK: 'black'>, <TileColor.YELLOW: 'yellow'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.BLUE: 'blue'>, <TileColor.WHITE: 'white'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.YELLOW: 'yellow'>, <TileColor.RED: 'red'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.RED: 'red'>, <TileColor.BLUE: 'blue'>, <TileColor.WHITE: 'white'>, <TileColor.YELLOW: 'yellow'>, <TileColor.BLUE: 'blue'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>], discard=[], factories=[[], [], [], [], []], center=[<TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>]), round_number=1, first_player_token_in_center=False, first_player_index=1, round_log=[])
# [0, 0]
# 1 LLMAgent(model='openai/gpt-oss-20b', last_raw='{"action_id": 1, "rationale": "Place the black tile into line 5, matching its current color and avoiding floor penalties while progressing toward a line completion."}', last_reasoning=None, provider_priority=('fireworks', 'together', 'novita/fp4'), last_status=200, last_error=None)
# Action(source_index=-1, color=<TileColor.BLACK: 'black'>, pattern_line=4, take_first_player_token=False)
# GameState(players=[PlayerBoard(pattern_lines=[[], [], [<TileColor.RED: 'red'>, <TileColor.RED: 'red'>], [<TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>], [<TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>]], wall=[[False, False, False, False, True], [False, False, False, True, False], [False, False, False, False, False], [False, False, False, False, False], [False, False, False, False, False]], floor_line=[], has_first_player_token=False, score=0), PlayerBoard(pattern_lines=[[], [], [<TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>], [<TileColor.BLUE: 'blue'>], [<TileColor.BLACK: 'black'>]], wall=[[False, False, False, True, False], [False, False, True, False, False], [False, False, False, False, False], [False, False, False, False, False], [False, False, False, False, False]], floor_line=[], has_first_player_token=False, score=1)], current_player=1, phase=<GamePhase.DRAFTING: 'drafting'>, supply=Supply(bag=[<TileColor.YELLOW: 'yellow'>, <TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>, <TileColor.RED: 'red'>, <TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>, <TileColor.WHITE: 'white'>, <TileColor.WHITE: 'white'>, <TileColor.RED: 'red'>, <TileColor.BLUE: 'blue'>, <TileColor.BLACK: 'black'>, <TileColor.RED: 'red'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.BLUE: 'blue'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>, <TileColor.YELLOW: 'yellow'>, <TileColor.BLUE: 'blue'>, <TileColor.RED: 'red'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.WHITE: 'white'>, <TileColor.YELLOW: 'yellow'>, <TileColor.WHITE: 'white'>, <TileColor.WHITE: 'white'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.WHITE: 'white'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.WHITE: 'white'>, <TileColor.RED: 'red'>, <TileColor.BLUE: 'blue'>, <TileColor.WHITE: 'white'>, <TileColor.BLACK: 'black'>, <TileColor.BLUE: 'blue'>, <TileColor.YELLOW: 'yellow'>, <TileColor.BLUE: 'blue'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.BLACK: 'black'>, <TileColor.RED: 'red'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.RED: 'red'>, <TileColor.BLACK: 'black'>, <TileColor.YELLOW: 'yellow'>, <TileColor.WHITE: 'white'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.BLUE: 'blue'>, <TileColor.BLACK: 'black'>, <TileColor.YELLOW: 'yellow'>], discard=[<TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>], factories=[[<TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.BLUE: 'blue'>, <TileColor.YELLOW: 'yellow'>], [<TileColor.WHITE: 'white'>, <TileColor.BLUE: 'blue'>, <TileColor.RED: 'red'>, <TileColor.BLACK: 'black'>], [<TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.WHITE: 'white'>, <TileColor.RED: 'red'>], [<TileColor.RED: 'red'>, <TileColor.YELLOW: 'yellow'>, <TileColor.WHITE: 'white'>, <TileColor.RED: 'red'>], [<TileColor.WHITE: 'white'>, <TileColor.BLUE: 'blue'>, <TileColor.WHITE: 'white'>, <TileColor.RED: 'red'>]], center=[]), round_number=2, first_player_token_in_center=True, first_player_index=1, round_log=[{'round': 1, 'player': 0, 'gained': 2, 'floor_penalty': -6, 'score_after': 0}, {'round': 1, 'player': 1, 'gained': 2, 'floor_penalty': -1, 'score_after': 1}])
# [0, 1]
# 0 LLMAgent(model='openai/gpt-oss-120b', last_raw='{"action_id":0,"rationale":"Only legal move: must take all three yellow tiles from center and place them on the floor line"}', last_reasoning=None, provider_priority=('fireworks', 'together', 'novita/fp4'), last_status=200, last_error=None)
# Action(source_index=-1, color=<TileColor.YELLOW: 'yellow'>, pattern_line=-1, take_first_player_token=False)
# GameState(players=[PlayerBoard(pattern_lines=[[], [], [<TileColor.RED: 'red'>, <TileColor.RED: 'red'>], [<TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>], [<TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>]], wall=[[False, False, False, False, True], [False, False, False, True, False], [False, False, False, False, False], [False, False, False, False, False], [False, False, False, False, False]], floor_line=[], has_first_player_token=False, score=0), PlayerBoard(pattern_lines=[[], [<TileColor.RED: 'red'>, <TileColor.RED: 'red'>], [<TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>], [<TileColor.BLUE: 'blue'>], [<TileColor.BLACK: 'black'>]], wall=[[False, False, False, True, False], [False, False, True, False, False], [False, False, False, False, False], [False, False, False, False, False], [False, False, False, False, False]], floor_line=[], has_first_player_token=False, score=1)], current_player=0, phase=<GamePhase.DRAFTING: 'drafting'>, supply=Supply(bag=[<TileColor.YELLOW: 'yellow'>, <TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>, <TileColor.RED: 'red'>, <TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>, <TileColor.WHITE: 'white'>, <TileColor.WHITE: 'white'>, <TileColor.RED: 'red'>, <TileColor.BLUE: 'blue'>, <TileColor.BLACK: 'black'>, <TileColor.RED: 'red'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.BLUE: 'blue'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>, <TileColor.YELLOW: 'yellow'>, <TileColor.BLUE: 'blue'>, <TileColor.RED: 'red'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.WHITE: 'white'>, <TileColor.YELLOW: 'yellow'>, <TileColor.WHITE: 'white'>, <TileColor.WHITE: 'white'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.WHITE: 'white'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.WHITE: 'white'>, <TileColor.RED: 'red'>, <TileColor.BLUE: 'blue'>, <TileColor.WHITE: 'white'>, <TileColor.BLACK: 'black'>, <TileColor.BLUE: 'blue'>, <TileColor.YELLOW: 'yellow'>, <TileColor.BLUE: 'blue'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.BLACK: 'black'>, <TileColor.RED: 'red'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.RED: 'red'>, <TileColor.BLACK: 'black'>, <TileColor.YELLOW: 'yellow'>, <TileColor.WHITE: 'white'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.BLUE: 'blue'>, <TileColor.BLACK: 'black'>, <TileColor.YELLOW: 'yellow'>], discard=[<TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>], factories=[[<TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.BLUE: 'blue'>, <TileColor.YELLOW: 'yellow'>], [<TileColor.WHITE: 'white'>, <TileColor.BLUE: 'blue'>, <TileColor.RED: 'red'>, <TileColor.BLACK: 'black'>], [<TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.WHITE: 'white'>, <TileColor.RED: 'red'>], [], [<TileColor.WHITE: 'white'>, <TileColor.BLUE: 'blue'>, <TileColor.WHITE: 'white'>, <TileColor.RED: 'red'>]], center=[<TileColor.YELLOW: 'yellow'>, <TileColor.WHITE: 'white'>]), round_number=2, first_player_token_in_center=True, first_player_index=1, round_log=[{'round': 1, 'player': 0, 'gained': 2, 'floor_penalty': -6, 'score_after': 0}, {'round': 1, 'player': 1, 'gained': 2, 'floor_penalty': -1, 'score_after': 1}])
# [0, 1]
# 1 LLMAgent(model='openai/gpt-oss-20b', last_raw='{"action_id": 0, "rationale": "Fill pattern line 2 with two reds to complete it and place a red tile in the wall, maximizing future scoring."}', last_reasoning=None, provider_priority=('fireworks', 'together', 'novita/fp4'), last_status=200, last_error=None)
# Action(source_index=3, color=<TileColor.RED: 'red'>, pattern_line=1, take_first_player_token=False)
# ...
# GameState(players=[PlayerBoard(pattern_lines=[[<TileColor.BLUE: 'blue'>], [<TileColor.YELLOW: 'yellow'>], [], [<TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>], [<TileColor.RED: 'red'>, <TileColor.RED: 'red'>, <TileColor.RED: 'red'>, <TileColor.RED: 'red'>]], wall=[[False, True, True, True, True], [True, False, False, True, True], [False, False, True, True, True], [False, False, False, False, False], [False, False, True, False, False]], floor_line=[], has_first_player_token=True, score=7), PlayerBoard(pattern_lines=[[], [], [<TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>], [<TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>], [<TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>]], wall=[[True, False, True, True, True], [True, True, True, True, False], [True, False, False, True, False], [False, False, False, True, False], [False, False, False, False, False]], floor_line=[<TileColor.BLACK: 'black'>], has_first_player_token=False, score=17)], current_player=1, phase=<GamePhase.DRAFTING: 'drafting'>, supply=Supply(bag=[], discard=[<TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.BLACK: 'black'>, <TileColor.RED: 'red'>, <TileColor.RED: 'red'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.WHITE: 'white'>, <TileColor.WHITE: 'white'>, <TileColor.WHITE: 'white'>, <TileColor.WHITE: 'white'>, <TileColor.RED: 'red'>, <TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.RED: 'red'>, <TileColor.RED: 'red'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.BLUE: 'blue'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.WHITE: 'white'>, <TileColor.WHITE: 'white'>, <TileColor.WHITE: 'white'>, <TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>, <TileColor.WHITE: 'white'>, <TileColor.WHITE: 'white'>, <TileColor.WHITE: 'white'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>], factories=[[], [], [], [], []], center=[<TileColor.WHITE: 'white'>, <TileColor.RED: 'red'>, <TileColor.RED: 'red'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.WHITE: 'white'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>]), round_number=5, first_player_token_in_center=False, first_player_index=0, round_log=[{'round': 1, 'player': 0, 'gained': 2, 'floor_penalty': -6, 'score_after': 0}, {'round': 1, 'player': 1, 'gained': 2, 'floor_penalty': -1, 'score_after': 1}, {'round': 2, 'player': 0, 'gained': 11, 'floor_penalty': -11, 'score_after': 0}, {'round': 2, 'player': 1, 'gained': 9, 'floor_penalty': -4, 'score_after': 6}, {'round': 3, 'player': 0, 'gained': 9, 'floor_penalty': -6, 'score_after': 3}, {'round': 3, 'player': 1, 'gained': 7, 'floor_penalty': -8, 'score_after': 5}, {'round': 4, 'player': 0, 'gained': 8, 'floor_penalty': -4, 'score_after': 7}, {'round': 4, 'player': 1, 'gained': 12, 'floor_penalty': 0, 'score_after': 17}])
# [7, 17]
# 0 LLMAgent(model='openai/gpt-oss-120b', last_raw='{"action_id": 1, "rationale": "Adds a red to the partially filled line 5, moving toward completing the line without overflow penalties and without giving the opponent immediate scoring advantage."}', last_reasoning=None, provider_priority=('fireworks', 'together', 'novita/fp4'), last_status=200, last_error=None)
# Action(source_index=3, color=<TileColor.RED: 'red'>, pattern_line=4, take_first_player_token=False)
# GameState(players=[PlayerBoard(pattern_lines=[[<TileColor.BLUE: 'blue'>], [<TileColor.YELLOW: 'yellow'>], [], [<TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>], [<TileColor.RED: 'red'>, <TileColor.RED: 'red'>, <TileColor.RED: 'red'>, <TileColor.RED: 'red'>]], wall=[[False, True, True, True, True], [True, False, False, True, True], [False, False, True, True, True], [False, False, False, False, False], [False, False, True, False, False]], floor_line=[], has_first_player_token=True, score=7), PlayerBoard(pattern_lines=[[], [], [<TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>], [<TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>], [<TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>]], wall=[[True, False, True, True, True], [True, True, True, True, False], [True, False, False, True, False], [False, False, False, True, False], [False, False, False, False, False]], floor_line=[<TileColor.BLACK: 'black'>, <TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>], has_first_player_token=False, score=17)], current_player=0, phase=<GamePhase.DRAFTING: 'drafting'>, supply=Supply(bag=[], discard=[<TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.BLACK: 'black'>, <TileColor.RED: 'red'>, <TileColor.RED: 'red'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.WHITE: 'white'>, <TileColor.WHITE: 'white'>, <TileColor.WHITE: 'white'>, <TileColor.WHITE: 'white'>, <TileColor.RED: 'red'>, <TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.RED: 'red'>, <TileColor.RED: 'red'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.BLUE: 'blue'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.WHITE: 'white'>, <TileColor.WHITE: 'white'>, <TileColor.WHITE: 'white'>, <TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>, <TileColor.WHITE: 'white'>, <TileColor.WHITE: 'white'>, <TileColor.WHITE: 'white'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>], factories=[[], [], [], [], []], center=[<TileColor.WHITE: 'white'>, <TileColor.RED: 'red'>, <TileColor.RED: 'red'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.WHITE: 'white'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>]), round_number=5, first_player_token_in_center=False, first_player_index=0, round_log=[{'round': 1, 'player': 0, 'gained': 2, 'floor_penalty': -6, 'score_after': 0}, {'round': 1, 'player': 1, 'gained': 2, 'floor_penalty': -1, 'score_after': 1}, {'round': 2, 'player': 0, 'gained': 11, 'floor_penalty': -11, 'score_after': 0}, {'round': 2, 'player': 1, 'gained': 9, 'floor_penalty': -4, 'score_after': 6}, {'round': 3, 'player': 0, 'gained': 9, 'floor_penalty': -6, 'score_after': 3}, {'round': 3, 'player': 1, 'gained': 7, 'floor_penalty': -8, 'score_after': 5}, {'round': 4, 'player': 0, 'gained': 8, 'floor_penalty': -4, 'score_after': 7}, {'round': 4, 'player': 1, 'gained': 12, 'floor_penalty': 0, 'score_after': 17}])
# [7, 17]
# 1 LLMAgent(model='openai/gpt-oss-20b', last_raw='{"action_id":0,"rationale":"All options incur the same floor penalty; choosing blue is neutral and keeps options open for future rounds."}', last_reasoning=None, provider_priority=('fireworks', 'together', 'novita/fp4'), last_status=200, last_error=None)
# Action(source_index=-1, color=<TileColor.BLUE: 'blue'>, pattern_line=-1, take_first_player_token=False)
# GameState(players=[PlayerBoard(pattern_lines=[[<TileColor.BLUE: 'blue'>], [<TileColor.YELLOW: 'yellow'>], [<TileColor.WHITE: 'white'>, <TileColor.WHITE: 'white'>, <TileColor.WHITE: 'white'>], [<TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>], [<TileColor.RED: 'red'>, <TileColor.RED: 'red'>, <TileColor.RED: 'red'>, <TileColor.RED: 'red'>]], wall=[[False, True, True, True, True], [True, False, False, True, True], [False, False, True, True, True], [False, False, False, False, False], [False, False, True, False, False]], floor_line=[<TileColor.WHITE: 'white'>], has_first_player_token=True, score=7), PlayerBoard(pattern_lines=[[], [], [<TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>], [<TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>], [<TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>]], wall=[[True, False, True, True, True], [True, True, True, True, False], [True, False, False, True, False], [False, False, False, True, False], [False, False, False, False, False]], floor_line=[<TileColor.BLACK: 'black'>, <TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>], has_first_player_token=False, score=17)], current_player=1, phase=<GamePhase.DRAFTING: 'drafting'>, supply=Supply(bag=[], discard=[<TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.BLACK: 'black'>, <TileColor.RED: 'red'>, <TileColor.RED: 'red'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.WHITE: 'white'>, <TileColor.WHITE: 'white'>, <TileColor.WHITE: 'white'>, <TileColor.WHITE: 'white'>, <TileColor.RED: 'red'>, <TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.RED: 'red'>, <TileColor.RED: 'red'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.BLUE: 'blue'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.WHITE: 'white'>, <TileColor.WHITE: 'white'>, <TileColor.WHITE: 'white'>, <TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>, <TileColor.WHITE: 'white'>, <TileColor.WHITE: 'white'>, <TileColor.WHITE: 'white'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>], factories=[[], [], [], [], []], center=[<TileColor.RED: 'red'>, <TileColor.RED: 'red'>, <TileColor.RED: 'red'>, <TileColor.RED: 'red'>]), round_number=5, first_player_token_in_center=False, first_player_index=0, round_log=[{'round': 1, 'player': 0, 'gained': 2, 'floor_penalty': -6, 'score_after': 0}, {'round': 1, 'player': 1, 'gained': 2, 'floor_penalty': -1, 'score_after': 1}, {'round': 2, 'player': 0, 'gained': 11, 'floor_penalty': -11, 'score_after': 0}, {'round': 2, 'player': 1, 'gained': 9, 'floor_penalty': -4, 'score_after': 6}, {'round': 3, 'player': 0, 'gained': 9, 'floor_penalty': -6, 'score_after': 3}, {'round': 3, 'player': 1, 'gained': 7, 'floor_penalty': -8, 'score_after': 5}, {'round': 4, 'player': 0, 'gained': 8, 'floor_penalty': -4, 'score_after': 7}, {'round': 4, 'player': 1, 'gained': 12, 'floor_penalty': 0, 'score_after': 17}])
# [7, 17]
# 0 LLMAgent(model='openai/gpt-oss-120b', last_raw='{\n  "action_id": 0,\n  "rationale": "Taking white fills line 3 for 4 wall points with only 1 floor penalty, net +3; red would give only 2 points and 3 floor penalties (net -2)."\n}', last_reasoning=None, provider_priority=('fireworks', 'together', 'novita/fp4'), last_status=200, last_error=None)
# Action(source_index=-1, color=<TileColor.WHITE: 'white'>, pattern_line=2, take_first_player_token=False)
# GameState(players=[PlayerBoard(pattern_lines=[[], [<TileColor.YELLOW: 'yellow'>], [], [], [<TileColor.RED: 'red'>, <TileColor.RED: 'red'>, <TileColor.RED: 'red'>, <TileColor.RED: 'red'>]], wall=[[True, True, True, True, True], [True, False, False, True, True], [False, True, True, True, True], [False, False, False, True, False], [False, False, True, False, False]], floor_line=[], has_first_player_token=False, score=22), PlayerBoard(pattern_lines=[[], [], [], [<TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>], []], wall=[[True, False, True, True, True], [True, True, True, True, False], [True, False, True, True, False], [False, False, False, True, False], [False, False, True, False, False]], floor_line=[], has_first_player_token=False, score=9)], current_player=1, phase=<GamePhase.GAME_END: 'game_end'>, supply=Supply(bag=[], discard=[<TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.BLACK: 'black'>, <TileColor.RED: 'red'>, <TileColor.RED: 'red'>, <TileColor.RED: 'red'>, <TileColor.WHITE: 'white'>, <TileColor.WHITE: 'white'>, <TileColor.WHITE: 'white'>, <TileColor.WHITE: 'white'>, <TileColor.WHITE: 'white'>, <TileColor.RED: 'red'>, <TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.RED: 'red'>, <TileColor.RED: 'red'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.BLUE: 'blue'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.WHITE: 'white'>, <TileColor.WHITE: 'white'>, <TileColor.WHITE: 'white'>, <TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>, <TileColor.WHITE: 'white'>, <TileColor.WHITE: 'white'>, <TileColor.WHITE: 'white'>, <TileColor.YELLOW: 'yellow'>, <TileColor.YELLOW: 'yellow'>, <TileColor.WHITE: 'white'>, <TileColor.WHITE: 'white'>, <TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>, <TileColor.WHITE: 'white'>, <TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.BLACK: 'black'>, <TileColor.BLUE: 'blue'>, <TileColor.BLUE: 'blue'>, <TileColor.RED: 'red'>, <TileColor.RED: 'red'>, <TileColor.RED: 'red'>, <TileColor.RED: 'red'>], factories=[[], [], [], [], []], center=[]), round_number=5, first_player_token_in_center=False, first_player_index=0, round_log=[{'round': 1, 'player': 0, 'gained': 2, 'floor_penalty': -6, 'score_after': 0}, {'round': 1, 'player': 1, 'gained': 2, 'floor_penalty': -1, 'score_after': 1}, {'round': 2, 'player': 0, 'gained': 11, 'floor_penalty': -11, 'score_after': 0}, {'round': 2, 'player': 1, 'gained': 9, 'floor_penalty': -4, 'score_after': 6}, {'round': 3, 'player': 0, 'gained': 9, 'floor_penalty': -6, 'score_after': 3}, {'round': 3, 'player': 1, 'gained': 7, 'floor_penalty': -8, 'score_after': 5}, {'round': 4, 'player': 0, 'gained': 8, 'floor_penalty': -4, 'score_after': 7}, {'round': 4, 'player': 1, 'gained': 12, 'floor_penalty': 0, 'score_after': 17}, {'round': 5, 'player': 0, 'gained': 15, 'floor_penalty': -2, 'score_after': 20}, {'round': 5, 'player': 1, 'gained': 6, 'floor_penalty': -14, 'score_after': 9}])
# [22, 9]
# 1 LLMAgent(model='openai/gpt-oss-20b', last_raw='{"action_id": 0, "rationale": "Only legal move available"}', last_reasoning=None, provider_priority=('fireworks', 'together', 'novita/fp4'), last_status=200, last_error=None)
# Action(source_index=-1, color=<TileColor.RED: 'red'>, pattern_line=-1, take_first_player_token=False)
# [22, 9]

# %%
# Inspect the last LLM reasoning/raw output after a game
llm_agent.last_reasoning, llm_agent.last_raw
# Out:
# (None,
#  '{\n  "action_id": 0,\n  "rationale": "Taking the single red tile adds only one more penalty (-2) to the floor, minimizing point loss and removes the only red from the center, forcing the opponent to take the two whites."\n}')

# %%
llm_agent.last_error

# %%
from evals.arena import run_arena
import os 
run_arena(
  ["openai/gpt-oss-120b", "google/gemini-3-flash-preview", "anthropic/claude-haiku-4.5", "openai/gpt-5-mini"],
  games_per_pair=16,
  parallel=24,
  out_dir="runs_final",
  providers=[["fireworks", "together"], None, None, None],
  progress=True,
  swap_sides=True
)
# Out:
# games:   0%|                                                                                                                                               | 0/96 [00:00<?, ?it/s]
# turns: 0it [00:06, ?it/s, g0 google/gemini-3-flash... vs openai/gpt-5-mini | 0-0]
# turns: 1it [00:06,  6.33s/it, g0 google/gemini-3-flash... vs openai/gpt-5-mini | 0-0]
# turns: 1it [00:06,  6.33s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 0-0]
# turns: 2it [00:06,  2.96s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 0-0]
# turns: 2it [00:07,  2.96s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 0-0]
# turns: 3it [00:07,  1.86s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 0-0]
# turns: 3it [00:10,  1.86s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 0-0]
# turns: 4it [00:10,  2.13s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 0-0]
# turns: 4it [00:14,  2.13s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 0-0]
# turns: 5it [00:14,  2.86s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 0-0]
# turns: 5it [00:15,  2.86s/it, g0 google/gemini-3-flash... vs anthropic/claude-haik... | 0-0]
# turns: 6it [00:15,  2.37s/it, g0 google/gemini-3-flash... vs anthropic/claude-haik... | 0-0]
# turns: 6it [00:16,  2.37s/it, g0 google/gemini-3-flash... vs anthropic/claude-haik... | 0-0]
# turns: 7it [00:16,  1.99s/it, g0 google/gemini-3-flash... vs anthropic/claude-haik... | 0-0]
# turns: 7it [00:20,  1.99s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 0-0]
# turns: 8it [00:20,  2.53s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 0-0]
# turns: 8it [00:24,  2.53s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 0-0]
# turns: 9it [00:24,  3.09s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 0-0]
# turns: 9it [00:25,  3.09s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 0-0]
# turns: 10it [00:25,  2.27s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 0-0]
# turns: 10it [00:25,  2.27s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 0-0]
# turns: 11it [00:25,  2.27s/it, g0 openai/gpt-5-mini vs anthropic/claude-haik... | 0-0]
# turns: 12it [00:25,  1.28s/it, g0 openai/gpt-5-mini vs anthropic/claude-haik... | 0-0]
# turns: 12it [00:26,  1.28s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 0-0]
# turns: 13it [00:26,  1.13s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 0-0]
# turns: 13it [00:26,  1.13s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 0-0]
# turns: 14it [00:26,  1.07it/s, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 0-0]
# turns: 14it [00:28,  1.07it/s, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 0-0]
# turns: 15it [00:28,  1.07s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 0-0]
# turns: 15it [00:29,  1.07s/it, g0 openai/gpt-5-mini vs anthropic/claude-haik... | 0-0]
# turns: 16it [00:29,  1.10s/it, g0 openai/gpt-5-mini vs anthropic/claude-haik... | 0-0]
# turns: 16it [00:29,  1.10s/it, g0 anthropic/claude-haik... vs google/gemini-3-flash... | 0-0]
# turns: 17it [00:29,  1.07it/s, g0 anthropic/claude-haik... vs google/gemini-3-flash... | 0-0]
# turns: 17it [00:29,  1.07it/s, g0 anthropic/claude-haik... vs openai/gpt-5-mini | 0-0]
# turns: 18it [00:31,  1.07it/s, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 0-0]
# turns: 19it [00:31,  1.09it/s, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 0-0]
# turns: 19it [00:31,  1.09it/s, g0 openai/gpt-5-mini vs anthropic/claude-haik... | 0-0]
# turns: 20it [00:31,  1.31it/s, g0 openai/gpt-5-mini vs anthropic/claude-haik... | 0-0]
# turns: 20it [00:31,  1.31it/s, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 0-0]
# turns: 21it [00:31,  1.64it/s, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 0-0]
# turns: 21it [00:33,  1.64it/s, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 0-0]
# turns: 22it [00:33,  1.12it/s, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 0-0]
# turns: 22it [00:34,  1.12it/s, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 0-0]
# turns: 23it [00:34,  1.16it/s, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 0-0]
# turns: 23it [00:37,  1.16it/s, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 0-0]
# turns: 24it [00:37,  1.57s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 0-0]
# turns: 24it [00:39,  1.57s/it, g0 openai/gpt-oss-120b vs openai/gpt-5-mini | 0-0]
# turns: 25it [00:39,  1.74s/it, g0 openai/gpt-oss-120b vs openai/gpt-5-mini | 0-0]
# turns: 25it [00:40,  1.74s/it, g0 anthropic/claude-haik... vs google/gemini-3-flash... | 0-0]
# turns: 26it [00:40,  1.74s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 0-0]
# turns: 27it [00:40,  1.01s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 0-0]
# turns: 27it [00:40,  1.01s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 0-0]
# turns: 28it [00:40,  1.12it/s, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 0-0]
# turns: 28it [00:44,  1.12it/s, g0 google/gemini-3-flash... vs openai/gpt-5-mini | 0-0]
# turns: 29it [00:44,  1.53s/it, g0 google/gemini-3-flash... vs openai/gpt-5-mini | 0-0]
# turns: 29it [00:46,  1.53s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 0-0]
# turns: 30it [00:46,  1.82s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 0-0]
# turns: 30it [00:47,  1.82s/it, g0 anthropic/claude-haik... vs openai/gpt-5-mini | 0-0]
# turns: 31it [00:47,  1.50s/it, g0 anthropic/claude-haik... vs openai/gpt-5-mini | 0-0]
# turns: 31it [00:47,  1.50s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 0-0]
# turns: 32it [00:47,  1.19s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 0-0]
# turns: 32it [00:48,  1.19s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 0-0]
# turns: 33it [00:48,  1.17s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 0-0]
# turns: 33it [00:49,  1.17s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 0-0]
# turns: 34it [00:49,  1.05s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 0-0]
# turns: 34it [00:51,  1.05s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 0-0]
# turns: 35it [00:51,  1.15s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 0-0]
# turns: 35it [00:51,  1.15s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 0-0]
# turns: 36it [00:51,  1.03s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 0-0]
# turns: 36it [00:51,  1.03s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 0-0]
# turns: 37it [00:57,  1.03s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 0-0]
# turns: 38it [00:57,  1.77s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 0-0]
# turns: 38it [01:01,  1.77s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 0-0]
# turns: 39it [01:01,  2.34s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 0-0]
# turns: 39it [01:01,  2.34s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 0-0]
# turns: 40it [01:01,  1.91s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 0-0]
# turns: 40it [01:02,  1.91s/it, g0 anthropic/claude-haik... vs openai/gpt-5-mini | 0-0]
# turns: 41it [01:02,  1.48s/it, g0 anthropic/claude-haik... vs openai/gpt-5-mini | 0-0]
# turns: 41it [01:04,  1.48s/it, g0 openai/gpt-oss-120b vs openai/gpt-5-mini | 0-0]
# turns: 42it [01:04,  1.72s/it, g0 openai/gpt-oss-120b vs openai/gpt-5-mini | 0-0]
# turns: 42it [01:05,  1.72s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 0-0]
# turns: 43it [01:05,  1.40s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 0-0]
# turns: 43it [01:06,  1.40s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 0-0]
# turns: 44it [01:06,  1.50s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 0-0]
# turns: 44it [01:12,  1.50s/it, g0 anthropic/claude-haik... vs openai/gpt-5-mini | 0-0]
# turns: 45it [01:12,  2.82s/it, g0 anthropic/claude-haik... vs openai/gpt-5-mini | 0-0]
# turns: 45it [01:15,  2.82s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 0-0]
# turns: 46it [01:15,  2.72s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 0-0]
# turns: 46it [01:15,  2.72s/it, g0 openai/gpt-5-mini vs anthropic/claude-haik... | 0-0]
# turns: 47it [01:17,  2.72s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 0-0]
# turns: 48it [01:17,  2.07s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 0-0]
# turns: 48it [01:18,  2.07s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 0-0]
# turns: 49it [01:18,  1.78s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 0-0]
# turns: 49it [01:23,  1.78s/it, g0 google/gemini-3-flash... vs anthropic/claude-haik... | 0-0]
# turns: 50it [01:23,  2.42s/it, g0 google/gemini-3-flash... vs anthropic/claude-haik... | 0-0]
# turns: 50it [01:23,  2.42s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 0-0]
# turns: 51it [01:25,  2.42s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 0-0]
# turns: 52it [01:25,  1.97s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 0-0]
# turns: 52it [01:26,  1.97s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 0-0]
# turns: 53it [01:26,  1.66s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 0-0]
# turns: 53it [01:27,  1.66s/it, g0 openai/gpt-oss-120b vs openai/gpt-5-mini | 0-0]
# turns: 54it [01:27,  1.61s/it, g0 openai/gpt-oss-120b vs openai/gpt-5-mini | 0-0]
# turns: 54it [01:28,  1.61s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 0-0]
# turns: 55it [01:28,  1.22s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 0-0]
# turns: 55it [01:28,  1.22s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 0-0]
# turns: 56it [01:28,  1.06s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 0-0]
# turns: 56it [01:28,  1.06s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 0-0]
# turns: 57it [01:28,  1.24it/s, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 0-0]
# turns: 57it [01:29,  1.24it/s, g0 openai/gpt-5-mini vs anthropic/claude-haik... | 0-0]
# turns: 58it [01:29,  1.32it/s, g0 openai/gpt-5-mini vs anthropic/claude-haik... | 0-0]
# turns: 58it [01:29,  1.32it/s, g0 google/gemini-3-flash... vs openai/gpt-5-mini | 0-0]
# turns: 59it [01:29,  1.70it/s, g0 google/gemini-3-flash... vs openai/gpt-5-mini | 0-0]
# turns: 59it [01:30,  1.70it/s, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 0-0]
# turns: 60it [01:30,  1.23it/s, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 0-0]
# turns: 60it [01:35,  1.23it/s, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 0-0]
# turns: 61it [01:35,  1.82s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 0-0]
# turns: 61it [01:37,  1.82s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 0-0]
# turns: 62it [01:37,  2.04s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 0-0]
# turns: 62it [01:39,  2.04s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 0-0]
# turns: 63it [01:39,  2.06s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 0-0]
# turns: 63it [01:40,  2.06s/it, g0 google/gemini-3-flash... vs anthropic/claude-haik... | 0-0]
# turns: 64it [01:40,  1.50s/it, g0 google/gemini-3-flash... vs anthropic/claude-haik... | 0-0]
# turns: 64it [01:40,  1.50s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 0-0]
# turns: 65it [01:40,  1.32s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 0-0]
# turns: 65it [01:44,  1.32s/it, g0 openai/gpt-5-mini vs anthropic/claude-haik... | 0-0]
# turns: 66it [01:44,  1.97s/it, g0 openai/gpt-5-mini vs anthropic/claude-haik... | 0-0]
# turns: 66it [01:44,  1.97s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 0-0]
# turns: 67it [01:44,  1.52s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 0-0]
# turns: 67it [01:46,  1.52s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 0-0]
# turns: 68it [01:46,  1.69s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 0-0]
# turns: 68it [01:48,  1.69s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 0-0]
# turns: 69it [01:48,  1.57s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 0-0]
# turns: 69it [01:48,  1.57s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 0-0]
# turns: 70it [01:48,  1.27s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 0-0]
# turns: 70it [01:49,  1.27s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 0-0]
# turns: 71it [01:49,  1.10s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 0-0]
# turns: 71it [01:50,  1.10s/it, g0 openai/gpt-5-mini vs anthropic/claude-haik... | 0-0]
# turns: 72it [01:50,  1.15s/it, g0 openai/gpt-5-mini vs anthropic/claude-haik... | 0-0]
# turns: 72it [01:51,  1.15s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 0-0]
# turns: 73it [01:51,  1.17s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 0-0]
# turns: 73it [01:53,  1.17s/it, g0 google/gemini-3-flash... vs anthropic/claude-haik... | 0-0]
# turns: 74it [01:53,  1.22s/it, g0 google/gemini-3-flash... vs anthropic/claude-haik... | 0-0]
# turns: 74it [01:53,  1.22s/it, g0 anthropic/claude-haik... vs openai/gpt-5-mini | 0-0]
# turns: 75it [01:53,  1.13it/s, g0 anthropic/claude-haik... vs openai/gpt-5-mini | 0-0]
# turns: 75it [01:53,  1.13it/s, g0 google/gemini-3-flash... vs anthropic/claude-haik... | 0-0]
# turns: 76it [01:53,  1.13it/s, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 0-0]
# turns: 77it [01:53,  1.99it/s, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 0-0]
# turns: 77it [01:56,  1.99it/s, g0 anthropic/claude-haik... vs openai/gpt-5-mini | 0-0]
# turns: 78it [01:56,  1.05s/it, g0 anthropic/claude-haik... vs openai/gpt-5-mini | 0-0]
# turns: 78it [01:56,  1.05s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 0-0]
# turns: 79it [01:56,  1.24it/s, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 0-0]
# turns: 79it [01:57,  1.24it/s, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 0-0]
# turns: 80it [01:57,  1.03it/s, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 0-0]
# turns: 80it [02:01,  1.03it/s, g0 anthropic/claude-haik... vs google/gemini-3-flash... | 0-0]
# turns: 81it [02:01,  1.61s/it, g0 anthropic/claude-haik... vs google/gemini-3-flash... | 0-0]
# turns: 81it [02:08,  1.61s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 0-0]
# turns: 82it [02:08,  3.40s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 0-0]
# turns: 82it [02:09,  3.40s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 0-0]
# turns: 83it [02:09,  2.64s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 0-0]
# turns: 83it [02:10,  2.64s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 0-0]
# turns: 84it [02:10,  2.20s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 0-0]
# turns: 84it [02:11,  2.20s/it, g0 anthropic/claude-haik... vs openai/gpt-oss-120b | 0-0]
# turns: 85it [02:11,  1.84s/it, g0 anthropic/claude-haik... vs openai/gpt-oss-120b | 0-0]
# turns: 85it [02:13,  1.84s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 0-0]
# turns: 86it [02:13,  1.66s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 0-0]
# turns: 86it [02:20,  1.66s/it, g0 openai/gpt-oss-120b vs openai/gpt-5-mini | 0-0]
# turns: 87it [02:20,  3.53s/it, g0 openai/gpt-oss-120b vs openai/gpt-5-mini | 0-0]
# turns: 87it [02:23,  3.53s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 0-0]
# turns: 88it [02:23,  3.17s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 0-0]
# turns: 88it [02:25,  3.17s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 0-0]
# turns: 89it [02:25,  2.87s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 0-0]
# turns: 89it [02:25,  2.87s/it, g0 google/gemini-3-flash... vs openai/gpt-5-mini | 0-0]
# turns: 90it [02:26,  2.87s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 0-0]
# turns: 91it [02:26,  1.71s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 0-0]
# turns: 91it [02:27,  1.71s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 0-0]
# turns: 92it [02:27,  1.63s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 0-0]
# turns: 92it [02:27,  1.63s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 0-0]
# turns: 93it [02:27,  1.31s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 0-0]
# turns: 93it [02:30,  1.31s/it, g0 openai/gpt-5-mini vs anthropic/claude-haik... | 0-0]
# turns: 94it [02:30,  1.72s/it, g0 openai/gpt-5-mini vs anthropic/claude-haik... | 0-0]
# turns: 94it [02:32,  1.72s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 0-0]
# turns: 95it [02:32,  1.80s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 0-0]
# turns: 95it [02:32,  1.80s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 0-0]
# turns: 96it [02:36,  1.80s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 0-0]
# turns: 97it [02:36,  1.74s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 0-0]
# turns: 97it [02:37,  1.74s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 0-0]
# turns: 98it [02:37,  1.62s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 0-0]
# turns: 98it [02:38,  1.62s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 0-0]
# turns: 99it [02:38,  1.54s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 0-0]
# turns: 99it [02:39,  1.54s/it, g0 anthropic/claude-haik... vs openai/gpt-5-mini | 0-0]
# turns: 100it [02:39,  1.32s/it, g0 anthropic/claude-haik... vs openai/gpt-5-mini | 0-0]
# turns: 100it [02:39,  1.32s/it, g0 anthropic/claude-haik... vs openai/gpt-oss-120b | 0-0]
# turns: 101it [02:39,  1.01s/it, g0 anthropic/claude-haik... vs openai/gpt-oss-120b | 0-0]
# turns: 101it [02:44,  1.01s/it, g0 openai/gpt-oss-120b vs openai/gpt-5-mini | 0-0]
# turns: 102it [02:44,  2.25s/it, g0 openai/gpt-oss-120b vs openai/gpt-5-mini | 0-0]
# turns: 102it [02:46,  2.25s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 0-0]
# turns: 103it [02:46,  2.02s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 0-0]
# turns: 103it [02:46,  2.02s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 0-0]
# turns: 104it [02:46,  1.55s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 0-0]
# turns: 104it [02:46,  1.55s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 0-0]
# turns: 105it [02:46,  1.12s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 0-0]
# turns: 105it [02:49,  1.12s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 0-0]
# turns: 106it [02:49,  1.56s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 0-0]
# turns: 106it [02:52,  1.56s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 0-0]
# turns: 107it [02:52,  2.06s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 0-0]
# turns: 107it [02:53,  2.06s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 0-0]
# turns: 108it [02:53,  1.59s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 0-0]
# turns: 108it [02:54,  1.59s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 0-0]
# turns: 109it [02:54,  1.61s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 0-0]
# turns: 109it [02:57,  1.61s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 0-0]
# turns: 110it [02:57,  1.91s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 0-0]
# turns: 110it [02:58,  1.91s/it, g0 anthropic/claude-haik... vs google/gemini-3-flash... | 0-0]
# turns: 111it [02:58,  1.67s/it, g0 anthropic/claude-haik... vs google/gemini-3-flash... | 0-0]
# turns: 111it [02:59,  1.67s/it, g0 openai/gpt-5-mini vs anthropic/claude-haik... | 0-0]
# turns: 112it [02:59,  1.34s/it, g0 openai/gpt-5-mini vs anthropic/claude-haik... | 0-0]
# turns: 112it [02:59,  1.34s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 0-0]
# turns: 113it [02:59,  1.12s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 0-0]
# turns: 113it [03:02,  1.12s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 0-0]
# turns: 114it [03:02,  1.64s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 0-0]
# turns: 114it [03:02,  1.64s/it, g0 anthropic/claude-haik... vs openai/gpt-5-mini | 0-0]
# turns: 115it [03:09,  1.64s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 0-0]
# turns: 116it [03:09,  2.49s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 0-0]
# turns: 116it [03:09,  2.49s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 0-0]
# turns: 117it [03:09,  1.94s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 0-0]
# turns: 117it [03:13,  1.94s/it, g0 google/gemini-3-flash... vs openai/gpt-5-mini | 0-0]
# turns: 118it [03:13,  2.30s/it, g0 google/gemini-3-flash... vs openai/gpt-5-mini | 0-0]
# turns: 118it [03:16,  2.30s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 0-0]
# turns: 119it [03:16,  2.47s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 0-0]
# turns: 119it [03:20,  2.47s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 0-0]
# turns: 120it [03:20,  3.11s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 0-0]
# turns: 120it [03:20,  3.11s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 0-0]
# turns: 121it [03:24,  3.11s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 0-0]
# turns: 122it [03:24,  2.45s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 0-0]
# turns: 122it [03:24,  2.45s/it, g0 anthropic/claude-haik... vs openai/gpt-5-mini | 0-0]
# turns: 123it [03:24,  1.91s/it, g0 anthropic/claude-haik... vs openai/gpt-5-mini | 0-0]
# turns: 123it [03:25,  1.91s/it, g0 google/gemini-3-flash... vs anthropic/claude-haik... | 0-0]
# turns: 124it [03:25,  1.62s/it, g0 google/gemini-3-flash... vs anthropic/claude-haik... | 0-0]
# turns: 124it [03:25,  1.62s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 0-0]
# turns: 125it [03:25,  1.39s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 0-0]
# turns: 125it [03:29,  1.39s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 0-0]
# turns: 126it [03:29,  1.95s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 0-0]
# turns: 126it [03:30,  1.95s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 0-0]
# turns: 127it [03:30,  1.81s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 0-0]
# turns: 127it [03:32,  1.81s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 4-4]
# turns: 128it [03:32,  1.69s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 4-4]
# turns: 128it [03:33,  1.69s/it, g0 openai/gpt-5-mini vs anthropic/claude-haik... | 0-0]
# turns: 129it [03:33,  1.46s/it, g0 openai/gpt-5-mini vs anthropic/claude-haik... | 0-0]
# turns: 129it [03:37,  1.46s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 0-0]
# turns: 130it [03:37,  2.27s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 0-0]
# turns: 130it [03:37,  2.27s/it, g0 openai/gpt-oss-120b vs openai/gpt-5-mini | 0-0]
# turns: 131it [03:37,  2.27s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 0-0]
# turns: 132it [03:37,  1.27s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 0-0]
# turns: 132it [03:37,  1.27s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 0-0]
# turns: 133it [03:37,  1.02s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 0-0]
# turns: 133it [03:37,  1.02s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 0-0]
# turns: 134it [03:40,  1.02s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 0-0]
# turns: 135it [03:40,  1.12s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 0-0]
# turns: 135it [03:40,  1.12s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 0-0]
# turns: 136it [03:40,  1.02it/s, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 0-0]
# turns: 136it [03:41,  1.02it/s, g0 anthropic/claude-haik... vs openai/gpt-5-mini | 0-0]
# turns: 137it [03:41,  1.00it/s, g0 anthropic/claude-haik... vs openai/gpt-5-mini | 0-0]
# turns: 137it [03:43,  1.00it/s, g0 openai/gpt-oss-120b vs openai/gpt-5-mini | 0-0]
# turns: 138it [03:43,  1.25s/it, g0 openai/gpt-oss-120b vs openai/gpt-5-mini | 0-0]
# turns: 138it [03:47,  1.25s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 0-0]
# turns: 139it [03:47,  1.80s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 0-0]
# turns: 139it [03:48,  1.80s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 0-0]
# turns: 140it [03:48,  1.73s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 0-0]
# turns: 140it [03:50,  1.73s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 0-0]
# turns: 141it [03:50,  1.66s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 0-0]
# turns: 141it [03:51,  1.66s/it, g0 anthropic/claude-haik... vs openai/gpt-oss-120b | 0-0]
# turns: 142it [03:51,  1.71s/it, g0 anthropic/claude-haik... vs openai/gpt-oss-120b | 0-0]
# turns: 142it [03:52,  1.71s/it, g0 anthropic/claude-haik... vs openai/gpt-5-mini | 0-0]
# turns: 143it [03:52,  1.32s/it, g0 anthropic/claude-haik... vs openai/gpt-5-mini | 0-0]
# turns: 143it [03:52,  1.32s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 0-0]
# turns: 144it [03:52,  1.02s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 0-0]
# turns: 144it [03:52,  1.02s/it, g0 google/gemini-3-flash... vs anthropic/claude-haik... | 0-0]
# turns: 145it [03:52,  1.31it/s, g0 google/gemini-3-flash... vs anthropic/claude-haik... | 0-0]
# turns: 145it [03:53,  1.31it/s, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 4-2]
# turns: 146it [03:53,  1.34it/s, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 4-2]
# turns: 146it [03:56,  1.34it/s, g0 openai/gpt-5-mini vs anthropic/claude-haik... | 0-0]
# turns: 147it [03:56,  1.35s/it, g0 openai/gpt-5-mini vs anthropic/claude-haik... | 0-0]
# turns: 147it [04:01,  1.35s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 0-0]
# turns: 148it [04:01,  2.41s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 0-0]
# turns: 148it [04:03,  2.41s/it, g0 google/gemini-3-flash... vs anthropic/claude-haik... | 0-0]
# turns: 149it [04:03,  2.36s/it, g0 google/gemini-3-flash... vs anthropic/claude-haik... | 0-0]
# turns: 149it [04:04,  2.36s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 0-0]
# turns: 150it [04:04,  1.90s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 0-0]
# turns: 150it [04:09,  1.90s/it, g0 google/gemini-3-flash... vs openai/gpt-5-mini | 0-0]
# turns: 151it [04:09,  2.97s/it, g0 google/gemini-3-flash... vs openai/gpt-5-mini | 0-0]
# turns: 151it [04:11,  2.97s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 0-0]
# turns: 152it [04:11,  2.75s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 0-0]
# turns: 152it [04:13,  2.75s/it, g0 anthropic/claude-haik... vs openai/gpt-oss-120b | 0-0]
# turns: 153it [04:13,  2.33s/it, g0 anthropic/claude-haik... vs openai/gpt-oss-120b | 0-0]
# turns: 153it [04:13,  2.33s/it, g0 google/gemini-3-flash... vs anthropic/claude-haik... | 0-0]
# turns: 154it [04:13,  1.74s/it, g0 google/gemini-3-flash... vs anthropic/claude-haik... | 0-0]
# turns: 154it [04:14,  1.74s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 0-0]
# turns: 155it [04:14,  1.56s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 0-0]
# turns: 155it [04:17,  1.56s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 4-2]
# turns: 156it [04:17,  1.85s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 4-2]
# turns: 156it [04:17,  1.85s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 0-0]
# turns: 157it [04:17,  1.38s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 0-0]
# turns: 157it [04:19,  1.38s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 0-0]
# turns: 158it [04:19,  1.41s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 0-0]
# turns: 158it [04:23,  1.41s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 3-1]
# turns: 159it [04:23,  2.21s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 3-1]
# turns: 159it [04:23,  2.21s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 0-0]
# turns: 160it [04:23,  1.77s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 0-0]
# turns: 160it [04:28,  1.77s/it, g0 anthropic/claude-haik... vs openai/gpt-5-mini | 0-0]
# turns: 161it [04:28,  2.49s/it, g0 anthropic/claude-haik... vs openai/gpt-5-mini | 0-0]
# turns: 161it [04:33,  2.49s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 0-0]
# turns: 162it [04:33,  3.33s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 0-0]
# turns: 162it [04:35,  3.33s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 4-4]
# turns: 163it [04:35,  2.99s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 4-4]
# turns: 163it [04:39,  2.99s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 0-0]
# turns: 164it [04:39,  3.38s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 0-0]
# turns: 164it [04:40,  3.38s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 0-0]
# turns: 165it [04:40,  2.51s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 0-0]
# turns: 165it [04:40,  2.51s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 0-0]
# turns: 166it [04:40,  1.93s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 0-0]
# turns: 166it [04:42,  1.93s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 4-2]
# turns: 167it [04:42,  1.82s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 4-2]
# turns: 167it [04:43,  1.82s/it, g0 openai/gpt-oss-120b vs openai/gpt-5-mini | 0-0]
# turns: 168it [04:43,  1.45s/it, g0 openai/gpt-oss-120b vs openai/gpt-5-mini | 0-0]
# turns: 168it [04:44,  1.45s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 0-0]
# turns: 169it [04:44,  1.47s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 0-0]
# turns: 169it [04:44,  1.47s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 4-3]
# turns: 170it [04:44,  1.09s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 4-3]
# turns: 170it [04:47,  1.09s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 0-0]
# turns: 171it [04:47,  1.63s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 0-0]
# turns: 171it [04:50,  1.63s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 0-0]
# turns: 172it [04:50,  1.87s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 0-0]
# turns: 172it [04:51,  1.87s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 0-0]
# turns: 173it [04:51,  1.63s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 0-0]
# turns: 173it [04:51,  1.63s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 0-0]
# turns: 174it [04:51,  1.39s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 0-0]
# turns: 174it [04:52,  1.39s/it, g0 google/gemini-3-flash... vs anthropic/claude-haik... | 0-0]
# turns: 175it [04:52,  1.24s/it, g0 google/gemini-3-flash... vs anthropic/claude-haik... | 0-0]
# turns: 175it [04:54,  1.24s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 3-3]
# turns: 176it [04:54,  1.34s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 3-3]
# turns: 176it [04:56,  1.34s/it, g0 openai/gpt-oss-120b vs openai/gpt-5-mini | 0-0]
# turns: 177it [04:56,  1.67s/it, g0 openai/gpt-oss-120b vs openai/gpt-5-mini | 0-0]
# turns: 177it [05:00,  1.67s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 3-3]
# turns: 178it [05:00,  2.39s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 3-3]
# turns: 178it [05:02,  2.39s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 1-3]
# turns: 179it [05:02,  2.22s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 1-3]
# turns: 179it [05:03,  2.22s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 0-0]
# turns: 180it [05:03,  1.68s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 0-0]
# turns: 180it [05:03,  1.68s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 3-2]
# turns: 181it [05:03,  1.38s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 3-2]
# turns: 181it [05:04,  1.38s/it, g0 openai/gpt-5-mini vs anthropic/claude-haik... | 0-0]
# turns: 182it [05:04,  1.19s/it, g0 openai/gpt-5-mini vs anthropic/claude-haik... | 0-0]
# turns: 182it [05:08,  1.19s/it, g0 anthropic/claude-haik... vs openai/gpt-5-mini | 0-0]
# turns: 183it [05:08,  1.90s/it, g0 anthropic/claude-haik... vs openai/gpt-5-mini | 0-0]
# turns: 183it [05:10,  1.90s/it, g0 anthropic/claude-haik... vs openai/gpt-5-mini | 0-0]
# turns: 184it [05:10,  2.10s/it, g0 anthropic/claude-haik... vs openai/gpt-5-mini | 0-0]
# turns: 184it [05:12,  2.10s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 0-0]
# turns: 185it [05:12,  1.94s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 0-0]
# turns: 185it [05:12,  1.94s/it, g0 google/gemini-3-flash... vs openai/gpt-5-mini | 0-0]
# turns: 186it [05:12,  1.45s/it, g0 google/gemini-3-flash... vs openai/gpt-5-mini | 0-0]
# turns: 186it [05:12,  1.45s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 4-2]
# turns: 187it [05:12,  1.06s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 4-2]
# turns: 187it [05:18,  1.06s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 3-1]
# turns: 188it [05:18,  2.41s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 3-1]
# turns: 188it [05:20,  2.41s/it, g0 google/gemini-3-flash... vs anthropic/claude-haik... | 0-0]
# turns: 189it [05:20,  2.26s/it, g0 google/gemini-3-flash... vs anthropic/claude-haik... | 0-0]
# turns: 189it [05:22,  2.26s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 2-2]
# turns: 190it [05:22,  2.35s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 2-2]
# turns: 190it [05:26,  2.35s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 4-3]
# turns: 191it [05:26,  2.85s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 4-3]
# turns: 191it [05:31,  2.85s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 0-0]
# turns: 192it [05:31,  3.42s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 0-0]
# turns: 192it [05:32,  3.42s/it, g0 openai/gpt-5-mini vs anthropic/claude-haik... | 0-0]
# turns: 193it [05:32,  2.60s/it, g0 openai/gpt-5-mini vs anthropic/claude-haik... | 0-0]
# turns: 193it [05:33,  2.60s/it, g0 anthropic/claude-haik... vs openai/gpt-5-mini | 0-0]
# turns: 194it [05:33,  2.33s/it, g0 anthropic/claude-haik... vs openai/gpt-5-mini | 0-0]
# turns: 194it [05:36,  2.33s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 2-3]
# turns: 195it [05:36,  2.39s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 2-3]
# turns: 195it [05:37,  2.39s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 0-0]
# turns: 196it [05:37,  1.86s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 0-0]
# turns: 196it [05:40,  1.86s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 3-3]
# turns: 197it [05:40,  2.40s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 3-3]
# turns: 197it [05:40,  2.40s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 0-0]
# turns: 198it [05:40,  1.72s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 0-0]
# turns: 198it [05:44,  1.72s/it, g0 openai/gpt-5-mini vs anthropic/claude-haik... | 0-0]
# turns: 199it [05:44,  2.29s/it, g0 openai/gpt-5-mini vs anthropic/claude-haik... | 0-0]
# turns: 199it [05:44,  2.29s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 2-4]
# turns: 200it [05:44,  1.65s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 2-4]
# turns: 200it [05:47,  1.65s/it, g0 google/gemini-3-flash... vs openai/gpt-5-mini | 0-0]
# turns: 201it [05:47,  1.91s/it, g0 google/gemini-3-flash... vs openai/gpt-5-mini | 0-0]
# turns: 201it [05:47,  1.91s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 4-2]
# turns: 202it [05:47,  1.47s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 4-2]
# turns: 202it [05:50,  1.47s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 3-2]
# turns: 203it [05:50,  1.94s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 3-2]
# turns: 203it [05:52,  1.94s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 2-2]
# turns: 204it [05:52,  2.00s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 2-2]
# turns: 204it [05:53,  2.00s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 4-4]
# turns: 205it [05:53,  1.75s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 4-4]
# turns: 205it [05:58,  1.75s/it, g0 openai/gpt-oss-120b vs openai/gpt-5-mini | 0-0]
# turns: 206it [05:58,  2.48s/it, g0 openai/gpt-oss-120b vs openai/gpt-5-mini | 0-0]
# turns: 206it [05:59,  2.48s/it, g0 anthropic/claude-haik... vs openai/gpt-oss-120b | 0-0]
# turns: 207it [05:59,  2.01s/it, g0 anthropic/claude-haik... vs openai/gpt-oss-120b | 0-0]
# turns: 207it [06:03,  2.01s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 2-3]
# turns: 208it [06:03,  2.72s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 2-3]
# turns: 208it [06:07,  2.72s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 1-2]
# turns: 209it [06:07,  2.99s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 1-2]
# turns: 209it [06:07,  2.99s/it, g0 google/gemini-3-flash... vs openai/gpt-5-mini | 0-0]
# turns: 210it [06:07,  2.26s/it, g0 google/gemini-3-flash... vs openai/gpt-5-mini | 0-0]
# turns: 210it [06:08,  2.26s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 3-1]
# turns: 211it [06:08,  1.93s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 3-1]
# turns: 211it [06:08,  1.93s/it, g0 openai/gpt-oss-120b vs openai/gpt-5-mini | 0-0]
# turns: 212it [06:08,  1.40s/it, g0 openai/gpt-oss-120b vs openai/gpt-5-mini | 0-0]
# turns: 212it [06:10,  1.40s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 2-2]
# turns: 213it [06:10,  1.47s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 2-2]
# turns: 213it [06:13,  1.47s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 2-4]
# turns: 214it [06:13,  1.88s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 2-4]
# turns: 214it [06:14,  1.88s/it, g0 anthropic/claude-haik... vs openai/gpt-oss-120b | 0-0]
# turns: 215it [06:14,  1.74s/it, g0 anthropic/claude-haik... vs openai/gpt-oss-120b | 0-0]
# turns: 215it [06:18,  1.74s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 3-3]
# turns: 216it [06:18,  2.41s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 3-3]
# turns: 216it [06:19,  2.41s/it, g0 google/gemini-3-flash... vs anthropic/claude-haik... | 0-0]
# turns: 217it [06:19,  2.04s/it, g0 google/gemini-3-flash... vs anthropic/claude-haik... | 0-0]
# turns: 217it [06:20,  2.04s/it, g0 anthropic/claude-haik... vs openai/gpt-5-mini | 0-0]
# turns: 218it [06:20,  1.74s/it, g0 anthropic/claude-haik... vs openai/gpt-5-mini | 0-0]
# turns: 218it [06:21,  1.74s/it, g0 anthropic/claude-haik... vs openai/gpt-5-mini | 0-0]
# turns: 219it [06:21,  1.27s/it, g0 anthropic/claude-haik... vs openai/gpt-5-mini | 0-0]
# turns: 219it [06:24,  1.27s/it, g0 openai/gpt-oss-120b vs openai/gpt-5-mini | 5-0]
# turns: 220it [06:24,  1.84s/it, g0 openai/gpt-oss-120b vs openai/gpt-5-mini | 5-0]
# turns: 220it [06:24,  1.84s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 1-3]
# turns: 221it [06:24,  1.41s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 1-3]
# turns: 221it [06:27,  1.41s/it, g0 google/gemini-3-flash... vs openai/gpt-5-mini | 5-2]
# turns: 222it [06:27,  1.95s/it, g0 google/gemini-3-flash... vs openai/gpt-5-mini | 5-2]
# turns: 222it [06:33,  1.95s/it, g0 openai/gpt-5-mini vs anthropic/claude-haik... | 0-0]
# turns: 223it [06:33,  3.13s/it, g0 openai/gpt-5-mini vs anthropic/claude-haik... | 0-0]
# turns: 223it [06:41,  3.13s/it, g0 openai/gpt-5-mini vs anthropic/claude-haik... | 0-0]
# turns: 224it [06:41,  4.53s/it, g0 openai/gpt-5-mini vs anthropic/claude-haik... | 0-0]
# turns: 224it [06:41,  4.53s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 4-4]
# turns: 225it [06:41,  3.24s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 4-4]
# turns: 225it [06:46,  3.24s/it, g0 google/gemini-3-flash... vs anthropic/claude-haik... | 0-0]
# turns: 226it [06:46,  3.68s/it, g0 google/gemini-3-flash... vs anthropic/claude-haik... | 0-0]
# turns: 226it [06:49,  3.68s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 3-3]
# turns: 227it [06:49,  3.44s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 3-3]
# turns: 227it [06:49,  3.44s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 4-3]
# turns: 228it [06:49,  2.46s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 4-3]
# turns: 228it [06:50,  2.46s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 1-2]
# turns: 229it [06:50,  2.03s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 1-2]
# turns: 229it [06:51,  2.03s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 2-2]
# turns: 230it [06:51,  1.74s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 2-2]
# turns: 230it [06:52,  1.74s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 4-2]
# turns: 231it [06:52,  1.43s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 4-2]
# turns: 231it [06:55,  1.43s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 3-1]
# turns: 232it [06:55,  2.06s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 3-1]
# turns: 232it [06:56,  2.06s/it, g0 anthropic/claude-haik... vs openai/gpt-5-mini | 0-0]
# turns: 233it [06:56,  1.64s/it, g0 anthropic/claude-haik... vs openai/gpt-5-mini | 0-0]
# turns: 233it [06:57,  1.64s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 1-3]
# turns: 234it [06:57,  1.56s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 1-3]
# turns: 234it [06:58,  1.56s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 3-3]
# turns: 235it [06:58,  1.31s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 3-3]
# turns: 235it [07:00,  1.31s/it, g0 anthropic/claude-haik... vs openai/gpt-5-mini | 0-0]
# turns: 236it [07:00,  1.32s/it, g0 anthropic/claude-haik... vs openai/gpt-5-mini | 0-0]
# turns: 236it [07:03,  1.32s/it, g0 openai/gpt-oss-120b vs openai/gpt-5-mini | 5-0]
# turns: 237it [07:03,  1.89s/it, g0 openai/gpt-oss-120b vs openai/gpt-5-mini | 5-0]
# turns: 237it [07:03,  1.89s/it, g0 anthropic/claude-haik... vs google/gemini-3-flash... | 0-0]
# turns: 238it [07:03,  1.39s/it, g0 anthropic/claude-haik... vs google/gemini-3-flash... | 0-0]
# turns: 238it [07:05,  1.39s/it, g0 google/gemini-3-flash... vs openai/gpt-5-mini | 5-2]
# turns: 239it [07:05,  1.45s/it, g0 google/gemini-3-flash... vs openai/gpt-5-mini | 5-2]
# turns: 239it [07:12,  1.45s/it, g0 openai/gpt-5-mini vs anthropic/claude-haik... | 0-0]
# turns: 240it [07:12,  3.13s/it, g0 openai/gpt-5-mini vs anthropic/claude-haik... | 0-0]
# turns: 240it [07:13,  3.13s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 3-2]
# turns: 241it [07:13,  2.74s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 3-2]
# turns: 241it [07:15,  2.74s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 4-4]
# turns: 242it [07:15,  2.29s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 4-4]
# turns: 242it [07:17,  2.29s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 3-3]
# turns: 243it [07:17,  2.36s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 3-3]
# turns: 243it [07:19,  2.36s/it, g0 google/gemini-3-flash... vs anthropic/claude-haik... | 0-0]
# turns: 244it [07:19,  2.18s/it, g0 google/gemini-3-flash... vs anthropic/claude-haik... | 0-0]
# turns: 244it [07:26,  2.18s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 1-2]
# turns: 245it [07:26,  3.63s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 1-2]
# turns: 245it [07:27,  3.63s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 2-4]
# turns: 246it [07:27,  2.73s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 2-4]
# turns: 246it [07:33,  2.73s/it, g0 google/gemini-3-flash... vs anthropic/claude-haik... | 0-0]
# turns: 247it [07:33,  3.96s/it, g0 google/gemini-3-flash... vs anthropic/claude-haik... | 0-0]
# turns: 247it [07:34,  3.96s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 4-3]
# turns: 248it [07:34,  2.80s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 4-3]
# turns: 248it [07:36,  2.80s/it, g0 openai/gpt-5-mini vs anthropic/claude-haik... | 0-0]
# turns: 249it [07:36,  2.75s/it, g0 openai/gpt-5-mini vs anthropic/claude-haik... | 0-0]
# turns: 249it [07:43,  2.75s/it, g0 openai/gpt-oss-120b vs openai/gpt-5-mini | 5-0]
# turns: 250it [07:43,  3.98s/it, g0 openai/gpt-oss-120b vs openai/gpt-5-mini | 5-0]
# turns: 250it [07:44,  3.98s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 3-2]
# turns: 251it [07:44,  3.18s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 3-2]
# turns: 251it [07:46,  3.18s/it, g0 anthropic/claude-haik... vs openai/gpt-5-mini | 0-0]
# turns: 252it [07:46,  2.85s/it, g0 anthropic/claude-haik... vs openai/gpt-5-mini | 0-0]
# turns: 252it [07:47,  2.85s/it, g0 openai/gpt-5-mini vs anthropic/claude-haik... | 0-0]
# turns: 253it [07:47,  2.09s/it, g0 openai/gpt-5-mini vs anthropic/claude-haik... | 0-0]
# turns: 253it [07:49,  2.09s/it, g0 anthropic/claude-haik... vs openai/gpt-oss-120b | 0-0]
# turns: 254it [07:49,  2.03s/it, g0 anthropic/claude-haik... vs openai/gpt-oss-120b | 0-0]
# turns: 254it [07:49,  2.03s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 1-3]
# turns: 255it [07:49,  2.03s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 2-2]
# turns: 256it [07:49,  1.25s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 2-2]
# turns: 256it [07:51,  1.25s/it, g0 anthropic/claude-haik... vs google/gemini-3-flash... | 0-0]
# turns: 257it [07:51,  1.36s/it, g0 anthropic/claude-haik... vs google/gemini-3-flash... | 0-0]
# turns: 257it [07:55,  1.36s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 4-2]
# turns: 258it [07:55,  2.16s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 4-2]
# turns: 258it [07:56,  2.16s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 2-3]
# turns: 259it [07:56,  1.80s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 2-3]
# turns: 259it [08:01,  1.80s/it, g0 anthropic/claude-haik... vs openai/gpt-oss-120b | 0-0]
# turns: 260it [08:01,  2.57s/it, g0 anthropic/claude-haik... vs openai/gpt-oss-120b | 0-0]
# turns: 260it [08:04,  2.57s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 3-3]
# turns: 261it [08:04,  2.86s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 3-3]
# turns: 261it [08:05,  2.86s/it, g0 openai/gpt-5-mini vs anthropic/claude-haik... | 0-0]
# turns: 262it [08:05,  2.28s/it, g0 openai/gpt-5-mini vs anthropic/claude-haik... | 0-0]
# turns: 262it [08:05,  2.28s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 3-2]
# turns: 263it [08:05,  1.66s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 3-2]
# turns: 263it [08:08,  1.66s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 2-4]
# turns: 264it [08:08,  2.02s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 2-4]
# turns: 264it [08:09,  2.02s/it, g0 anthropic/claude-haik... vs openai/gpt-5-mini | 0-0]
# turns: 265it [08:09,  1.53s/it, g0 anthropic/claude-haik... vs openai/gpt-5-mini | 0-0]
# turns: 265it [08:10,  1.53s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 1-2]
# turns: 266it [08:10,  1.53s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 1-2]
# turns: 266it [08:12,  1.53s/it, g0 google/gemini-3-flash... vs openai/gpt-5-mini | 5-2]
# turns: 267it [08:12,  1.54s/it, g0 google/gemini-3-flash... vs openai/gpt-5-mini | 5-2]
# turns: 267it [08:16,  1.54s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 4-4]
# turns: 268it [08:16,  2.34s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 4-4]
# turns: 268it [08:17,  2.34s/it, g0 anthropic/claude-haik... vs openai/gpt-5-mini | 0-0]
# turns: 269it [08:17,  1.80s/it, g0 anthropic/claude-haik... vs openai/gpt-5-mini | 0-0]
# turns: 269it [08:20,  1.80s/it, g0 openai/gpt-oss-120b vs openai/gpt-5-mini | 5-0]
# turns: 270it [08:20,  2.38s/it, g0 openai/gpt-oss-120b vs openai/gpt-5-mini | 5-0]
# turns: 270it [08:27,  2.38s/it, g0 anthropic/claude-haik... vs openai/gpt-5-mini | 0-0]
# turns: 271it [08:27,  3.71s/it, g0 anthropic/claude-haik... vs openai/gpt-5-mini | 0-0]
# turns: 271it [08:28,  3.71s/it, g0 openai/gpt-5-mini vs anthropic/claude-haik... | 0-0]
# turns: 272it [08:28,  2.86s/it, g0 openai/gpt-5-mini vs anthropic/claude-haik... | 0-0]
# turns: 272it [08:28,  2.86s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 3-1]
# turns: 273it [08:28,  2.07s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 3-1]
# turns: 273it [08:30,  2.07s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 2-3]
# turns: 274it [08:30,  1.95s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 2-3]
# turns: 274it [08:31,  1.95s/it, g0 anthropic/claude-haik... vs openai/gpt-5-mini | 3-3]
# turns: 275it [08:31,  1.58s/it, g0 anthropic/claude-haik... vs openai/gpt-5-mini | 3-3]
# turns: 275it [08:34,  1.58s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 1-3]
# turns: 276it [08:34,  2.09s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 1-3]
# turns: 276it [08:40,  2.09s/it, g0 google/gemini-3-flash... vs anthropic/claude-haik... | 0-0]
# ...
# turns: 850it [31:37,  3.88s/it, g0 anthropic/claude-haik... vs google/gemini-3-flash... | 5-8]
# turns: 850it [31:38,  3.88s/it, g0 anthropic/claude-haik... vs openai/gpt-5-mini | 5-12]
# turns: 851it [31:38,  3.22s/it, g0 anthropic/claude-haik... vs openai/gpt-5-mini | 5-12]
# turns: 851it [31:42,  3.22s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 23-18]
# turns: 852it [31:42,  3.21s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 23-18]
# turns: 852it [31:42,  3.21s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 28-21]
# turns: 853it [31:42,  2.41s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 28-21]
# turns: 853it [31:45,  2.41s/it, g0 anthropic/claude-haik... vs openai/gpt-5-mini | 13-4]
# turns: 854it [31:45,  2.54s/it, g0 anthropic/claude-haik... vs openai/gpt-5-mini | 13-4]
# turns: 854it [31:46,  2.54s/it, g0 openai/gpt-5-mini vs anthropic/claude-haik... | 3-1]
# turns: 855it [31:46,  2.01s/it, g0 openai/gpt-5-mini vs anthropic/claude-haik... | 3-1]
# turns: 855it [31:48,  2.01s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 16-26]
# turns: 856it [31:48,  2.21s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 16-26]
# turns: 856it [31:50,  2.21s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 35-13]
# turns: 857it [31:50,  1.96s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 35-13]
# turns: 857it [31:50,  1.96s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 1-13]
# turns: 858it [31:50,  1.96s/it, g0 google/gemini-3-flash... vs openai/gpt-5-mini | 16-13]
# turns: 859it [31:50,  1.20s/it, g0 google/gemini-3-flash... vs openai/gpt-5-mini | 16-13]
# turns: 859it [31:55,  1.20s/it, g0 openai/gpt-5-mini vs anthropic/claude-haik... | 17-6]
# turns: 860it [31:55,  2.12s/it, g0 openai/gpt-5-mini vs anthropic/claude-haik... | 17-6]
# turns: 860it [31:56,  2.12s/it, g0 openai/gpt-oss-120b vs openai/gpt-5-mini | 2-20]
# turns: 861it [31:56,  1.76s/it, g0 openai/gpt-oss-120b vs openai/gpt-5-mini | 2-20]
# turns: 861it [31:59,  1.76s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 1-13]
# turns: 862it [31:59,  2.21s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 1-13]
# turns: 862it [32:04,  2.21s/it, g0 anthropic/claude-haik... vs openai/gpt-5-mini | 6-5]
# turns: 863it [32:04,  2.85s/it, g0 anthropic/claude-haik... vs openai/gpt-5-mini | 6-5]
# turns: 863it [32:06,  2.85s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 41-23]
# turns: 864it [32:06,  2.53s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 41-23]LLMAgent fallback to random action after 2 attempts (model=anthropic/claude-haiku-4.5 status=200 error=None reason=json_decode_error raw=Looking at this game state, I need to determine which move progresses my position best.  **Current Situation Analysis:** - Player 1 (me) has score 0 - Pattern line 3: [black] (1/3, needs 2 more) - Pat...)
#
# turns: 864it [32:07,  2.53s/it, g0 google/gemini-3-flash... vs anthropic/claude-haik... | 3-0]
# turns: 865it [32:07,  2.24s/it, g0 google/gemini-3-flash... vs anthropic/claude-haik... | 3-0]
# turns: 865it [32:09,  2.24s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 26-20]
# turns: 866it [32:09,  2.15s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 26-20]
# turns: 866it [32:14,  2.15s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 35-13]
# turns: 867it [32:14,  2.83s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 35-13]
# turns: 867it [32:14,  2.83s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 19-9]
# turns: 868it [32:14,  2.07s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 19-9]
# turns: 868it [32:16,  2.07s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 26-26]
# turns: 869it [32:16,  2.24s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 26-26]
# turns: 869it [32:17,  2.24s/it, g0 openai/gpt-5-mini vs anthropic/claude-haik... | 6-3]
# turns: 870it [32:17,  2.24s/it, g0 anthropic/claude-haik... vs openai/gpt-5-mini | 5-12]
# turns: 871it [32:17,  1.39s/it, g0 anthropic/claude-haik... vs openai/gpt-5-mini | 5-12]
# turns: 871it [32:18,  1.39s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 1-13]
# turns: 872it [32:18,  1.25s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 1-13]
# turns: 872it [32:24,  1.25s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 16-26]
# turns: 873it [32:24,  2.38s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 16-26]
# turns: 873it [32:27,  2.38s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 9-23]
# turns: 874it [32:27,  2.64s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 9-23]
# turns: 874it [32:27,  2.64s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 16-21]
# turns: 875it [32:27,  2.03s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 16-21]
# turns: 875it [32:32,  2.03s/it, g0 openai/gpt-oss-120b vs openai/gpt-5-mini | 2-20]
# turns: 876it [32:32,  2.62s/it, g0 openai/gpt-oss-120b vs openai/gpt-5-mini | 2-20]
# turns: 876it [32:32,  2.62s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 15-39]
# turns: 877it [32:32,  2.62s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 28-21]
# turns: 878it [32:32,  1.63s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 28-21]
# turns: 878it [32:33,  1.63s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 41-23]
# turns: 879it [32:33,  1.44s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 41-23]
# turns: 879it [32:35,  1.44s/it, g0 openai/gpt-oss-120b vs openai/gpt-5-mini | 8-45]
# games:   1%|█▎                                                                                                                                | 1/96 [32:35<51:35:47, 1955.24s/it]
# turns: 880it [32:39,  1.47s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 35-13]
# turns: 881it [32:39,  2.19s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 35-13]
# turns: 881it [32:40,  2.19s/it, g0 google/gemini-3-flash... vs anthropic/claude-haik... | 3-0]
# turns: 882it [32:40,  1.82s/it, g0 google/gemini-3-flash... vs anthropic/claude-haik... | 3-0]
# turns: 882it [32:40,  1.82s/it, g0 google/gemini-3-flash... vs openai/gpt-5-mini | 16-13]
# turns: 883it [32:40,  1.34s/it, g0 google/gemini-3-flash... vs openai/gpt-5-mini | 16-13]
# turns: 883it [32:43,  1.34s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 28-21]
# turns: 884it [32:43,  1.92s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 28-21]
# turns: 884it [32:46,  1.92s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 16-26]
# turns: 885it [32:46,  2.10s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 16-26]
# turns: 885it [32:48,  2.10s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 16-25]
# games:   2%|██▋                                                                                                                                | 2/96 [32:48<21:13:33, 812.91s/it]
# turns: 886it [32:49,  2.16s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 16-21]
# turns: 887it [32:49,  1.81s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 16-21]
# turns: 887it [32:52,  1.81s/it, g0 openai/gpt-5-mini vs anthropic/claude-haik... | 6-3]
# turns: 888it [32:52,  2.08s/it, g0 openai/gpt-5-mini vs anthropic/claude-haik... | 6-3]
# turns: 888it [32:53,  2.08s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 55-27]
# games:   3%|████                                                                                                                               | 3/96 [32:53<11:28:05, 443.93s/it]
# turns: 889it [32:54,  1.80s/it, g0 openai/gpt-5-mini vs anthropic/claude-haik... | 2-1]
# turns: 890it [32:54,  1.71s/it, g0 openai/gpt-5-mini vs anthropic/claude-haik... | 2-1]
# turns: 890it [32:55,  1.71s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 23-18]
# turns: 891it [32:55,  1.43s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 23-18]
# turns: 891it [32:58,  1.43s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 41-23]
# turns: 892it [32:58,  1.93s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 41-23]
# turns: 892it [32:58,  1.93s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 29-32]
# turns: 893it [33:01,  1.93s/it, g0 google/gemini-3-flash... vs openai/gpt-5-mini | 0-0]
# turns: 894it [33:01,  1.59s/it, g0 google/gemini-3-flash... vs openai/gpt-5-mini | 0-0]
# turns: 894it [33:02,  1.59s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 19-9]
# turns: 895it [33:02,  1.53s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 19-9]
# turns: 895it [33:03,  1.53s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 0-0]
# turns: 896it [33:03,  1.42s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 0-0]
# turns: 896it [33:05,  1.42s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 66-47]
# games:   4%|█████▌                                                                                                                              | 4/96 [33:05<6:59:18, 273.46s/it]
# turns: 897it [33:08,  1.55s/it, g0 anthropic/claude-haik... vs openai/gpt-5-mini | 13-4]
# turns: 898it [33:08,  1.81s/it, g0 anthropic/claude-haik... vs openai/gpt-5-mini | 13-4]
# turns: 898it [33:09,  1.81s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 15-39]
# turns: 899it [33:09,  1.71s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 15-39]
# turns: 899it [33:10,  1.71s/it, g0 google/gemini-3-flash... vs openai/gpt-5-mini | 16-13]
# turns: 900it [33:10,  1.44s/it, g0 google/gemini-3-flash... vs openai/gpt-5-mini | 16-13]
# turns: 900it [33:11,  1.44s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 16-26]
# turns: 901it [33:11,  1.53s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 16-26]
# turns: 901it [33:16,  1.53s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 30-24]
# turns: 902it [33:16,  2.49s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 30-24]
# turns: 902it [33:19,  2.49s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 26-20]
# turns: 903it [33:19,  2.44s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 26-20]
# turns: 903it [33:21,  2.44s/it, g0 google/gemini-3-flash... vs openai/gpt-5-mini | 22-29]
# turns: 904it [33:21,  2.42s/it, g0 google/gemini-3-flash... vs openai/gpt-5-mini | 22-29]
# turns: 904it [33:22,  2.42s/it, g0 openai/gpt-5-mini vs anthropic/claude-haik... | 2-1]
# turns: 905it [33:22,  2.15s/it, g0 openai/gpt-5-mini vs anthropic/claude-haik... | 2-1]
# turns: 905it [33:25,  2.15s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 23-18]
# turns: 906it [33:25,  2.19s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 23-18]
# turns: 906it [33:25,  2.19s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 0-0]
# turns: 907it [33:25,  1.69s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 0-0]
# turns: 907it [33:26,  1.69s/it, g0 anthropic/claude-haik... vs google/gemini-3-flash... | 5-8]
# turns: 908it [33:26,  1.27s/it, g0 anthropic/claude-haik... vs google/gemini-3-flash... | 5-8]
# turns: 908it [33:33,  1.27s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 0-0]
# turns: 909it [33:33,  3.17s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 0-0]
# turns: 909it [33:36,  3.17s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 0-0]
# turns: 910it [33:36,  3.09s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 0-0]
# turns: 910it [33:38,  3.09s/it, g0 anthropic/claude-haik... vs openai/gpt-oss-120b | 0-0]
# turns: 911it [33:38,  2.88s/it, g0 anthropic/claude-haik... vs openai/gpt-oss-120b | 0-0]
# turns: 911it [33:40,  2.88s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 19-9]
# turns: 912it [33:40,  2.56s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 19-9]
# turns: 912it [33:42,  2.56s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 26-26]
# turns: 913it [33:42,  2.23s/it, g0 openai/gpt-5-mini vs openai/gpt-oss-120b | 26-26]
# turns: 913it [33:44,  2.23s/it, g0 anthropic/claude-haik... vs google/gemini-3-flash... | 5-8]
# turns: 914it [33:44,  2.23s/it, g0 anthropic/claude-haik... vs google/gemini-3-flash... | 5-8]
# turns: 914it [33:48,  2.23s/it, g0 google/gemini-3-flash... vs openai/gpt-5-mini | 0-0]
# turns: 915it [33:48,  2.70s/it, g0 google/gemini-3-flash... vs openai/gpt-5-mini | 0-0]
# turns: 915it [33:49,  2.70s/it, g0 anthropic/claude-haik... vs openai/gpt-oss-120b | 0-0]
# turns: 916it [33:49,  2.25s/it, g0 anthropic/claude-haik... vs openai/gpt-oss-120b | 0-0]
# turns: 916it [33:52,  2.25s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 28-21]
# turns: 917it [33:52,  2.63s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 28-21]
# turns: 917it [33:53,  2.63s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 15-39]
# turns: 918it [33:53,  2.04s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 15-39]
# turns: 918it [33:54,  2.04s/it, g0 anthropic/claude-haik... vs openai/gpt-oss-120b | 0-6]
# turns: 919it [33:54,  1.66s/it, g0 anthropic/claude-haik... vs openai/gpt-oss-120b | 0-6]
# turns: 919it [33:54,  1.66s/it, g0 openai/gpt-5-mini vs anthropic/claude-haik... | 6-3]
# turns: 920it [33:54,  1.19s/it, g0 openai/gpt-5-mini vs anthropic/claude-haik... | 6-3]
# turns: 920it [33:59,  1.19s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 0-0]
# turns: 921it [33:59,  2.22s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 0-0]
# turns: 921it [33:59,  2.22s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 57-24]
# games:   5%|██████▉                                                                                                                             | 5/96 [33:59<4:54:44, 194.34s/it]
# turns: 922it [34:05,  1.68s/it, g0 google/gemini-3-flash... vs anthropic/claude-haik... | 3-7]
# turns: 923it [34:05,  3.08s/it, g0 google/gemini-3-flash... vs anthropic/claude-haik... | 3-7]
# turns: 923it [34:06,  3.08s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 0-0]
# turns: 924it [34:06,  2.29s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 0-0]
# turns: 924it [34:06,  2.29s/it, g0 anthropic/claude-haik... vs openai/gpt-5-mini | 13-4]
# turns: 925it [34:06,  1.65s/it, g0 anthropic/claude-haik... vs openai/gpt-5-mini | 13-4]
# turns: 925it [34:07,  1.65s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 30-24]
# turns: 926it [34:07,  1.32s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 30-24]
# turns: 926it [34:07,  1.32s/it, g0 openai/gpt-oss-120b vs anthropic/claude-haik... | 0-0]
# turns: 927it [34:08,  1.32s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 23-18]
# turns: 928it [34:08,  1.10s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 23-18]
# turns: 928it [34:13,  1.10s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 16-26]
# turns: 929it [34:13,  2.00s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 16-26]
# turns: 929it [34:16,  2.00s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 26-20]
# turns: 930it [34:16,  2.23s/it, g0 openai/gpt-oss-120b vs google/gemini-3-flash... | 26-20]
# turns: 930it [34:16,  2.23s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 37-26]
# turns: 931it [34:16,  1.70s/it, g0 google/gemini-3-flash... vs openai/gpt-oss-120b | 37-26]
# turns: 931it [34:19,  1.70s/it, g0 google/gemini-3-flash... vs openai/gpt-5-mini | 0-0]
# turns: 932it [34:19,  2.00s/it, g0 google/gemini-3-flash... vs openai/gpt-5-mini | 0-0]
# turns: 932it [34:20,  2.00s/it, g0 openai/gpt-5-mini vs anthropic/claude-haik... | 2-1]
# turns: 933it [34:20,  1.85s/it, g0 openai/gpt-5-mini vs anthropic/claude-haik... | 2-1]
# turns: 933it [34:30,  1.85s/it, g0 openai/gpt-5-mini vs anthropic/claude-haik... | 8-6]
# turns: 934it [34:30,  4.11s/it, g0 openai/gpt-5-mini vs anthropic/claude-haik... | 8-6]
# turns: 934it [34:31,  4.11s/it, g0 openai/gpt-5-mini vs anthropic/claude-haik... | 6-3]
# turns: 935it [34:31,  3.06s/it, g0 openai/gpt-5-mini vs anthropic/claude-haik... | 6-3]
# turns: 935it [34:31,  3.06s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 0-0]
# turns: 936it [34:31,  2.26s/it, g0 openai/gpt-5-mini vs google/gemini-3-flash... | 0-0]

# %%
#!uv pip install tqdm
from tqdm import tqdm

# %%
  from analysis import summarize
  results, matchups = summarize("runs_test")
# Out:
# model_a                        model_b              total  wins_a  wins_b  draws  wr_a  wr_b
# google/gemini-3-flash-preview  openai/gpt-oss-120b  6      4       2       0      0.67  0.33
# google/gemini-3-flash-preview  openai/gpt-oss-20b   6      6       0       0      1.00  0.00
# openai/gpt-oss-120b            openai/gpt-oss-20b   6      6       0       0      1.00  0.00
